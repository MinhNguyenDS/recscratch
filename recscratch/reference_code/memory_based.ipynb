# %% [markdown]
# # Recommendation system from scratch

# %% [markdown]
# ## Import libraries

# %%
import time

from numpy import sqrt
from numpy import dot
from numpy.linalg import norm

import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split

sns.set()

# %% [markdown]
# ## Import data

# %%
# Load a rating file
ratings = pd.read_csv('../../recomendation_scratch/data_example/Movielens/ml-latest-small/ratings_test.csv')

# %%
ratings
# Out:
#        userId  movieId  rating   timestamp
# 0           1        1     4.0   964982703
# 1           5        1     4.0   847434962
# 2           7        1     4.5  1106635946
# 3          15        1     2.5  1510577970
# 4          17        1     4.5  1305696483
# ...       ...      ...     ...         ...
# 20565     587      910     4.0   953137911
# 20566     590      910     5.0  1258418246
# 20567     599      910     2.5  1498516800
# 20568     603      910     4.0   953926507
# 20569     606      910     5.0  1171236625
#
# [20570 rows x 4 columns]

# %%
X_train, X_test = train_test_split(ratings, test_size=0.2, random_state=42)
print('Train size:', len(X_train))
print('Test size:', len(X_test))
# Out:
# Train size: 16456
# Test size: 4114

# %%
X_train.userId.value_counts()
# Out:
# 5857    101
# 5954     98
# 5961     62
# 5972     58
# 9325     45
#        ...
# 6419      2
# 9341      2
# 5893      2
# 4766      2
# 6786      1
# Name: userId, Length: 485, dtype: int64

# %%
X_train.movieId.value_counts()
# Out:
# 246    69
# 269    63
# 417    56
# 212    52
# 347    50
#        ..
# 491     1
# 344     1
# 219     1
# 62      1
# 245     1
# Name: movieId, Length: 507, dtype: int64

# %%
X_test
# Out:
#        userId  movieId  rating     timestamp
# 1621     5932      307    10.0  1.458000e+09
# 2605     2542      412    10.0  1.485994e+09
# 4890      944      301     6.0  1.543363e+09
# 2040     5857      228     8.0  1.472083e+09
# 5399     5885      139     6.6  1.553904e+09
# ...       ...      ...     ...           ...
# 5365     5972      210     9.0  1.552867e+09
# 15687    5914      394     8.8  1.679098e+09
# 1896     5961      128     6.0  1.468109e+09
# 6694     6786       65     6.3  1.578442e+09
# 2045      934      549     8.5  1.472256e+09
#
# [959 rows x 4 columns]

# %% [markdown]
# ## Collaborative Filtering based on User

# %%
# get rating from the user-item pair
def get_rating(userid,movieid):
    return (ratings.loc[(ratings.userId==userid) & (ratings.movieId == movieid),'rating'].iloc[0])

### Pearson calculation
def pearson_correlation_score(user1, user2):
  both_watch_count = []
  list_movie_user1 = ratings.loc[ratings.userId == user1, 'movieId'].to_list()
  list_movie_user2 = ratings.loc[ratings.userId == user2, 'movieId'].to_list()

  for element in list_movie_user1:
    if element in list_movie_user2:
       both_watch_count.append(element)

  if(len(both_watch_count) == 0):
    return 0;

  rating_sum_1 = sum([get_rating(user1, i) for i in both_watch_count])
  avg_rating_sum_1 = rating_sum_1/len(both_watch_count)

  rating_sum_2 = sum([get_rating(user2, i) for i in both_watch_count])
  avg_rating_sum_2 = rating_sum_2/len(both_watch_count)

  tu = sum([(get_rating(user1, i) - avg_rating_sum_1)*(get_rating(user2, i) - avg_rating_sum_2)  for i in both_watch_count])
  mau = sqrt(sum([pow((get_rating(user1, i) - avg_rating_sum_1),2) for i in both_watch_count]))*sqrt(sum([pow((get_rating(user2, i) - avg_rating_sum_2),2) for i in both_watch_count]))

  if(mau ==0):
    return 0

  return tu/mau

### Cosine calculation
def distance_similarity_score(user1,user2):
    both_watch_count = 0
    for element in ratings.loc[ratings.userId==user1,'movieId'].tolist():
        if element in ratings.loc[ratings.userId==user2,'movieId'].tolist():
            both_watch_count += 1
    if both_watch_count == 0 :
        return 0

    rating1 = []
    rating2 = []
    for element in ratings.loc[ratings.userId==user1,'movieId'].tolist():
        if element in ratings.loc[ratings.userId==user2,'movieId'].tolist():
            rating1.append(get_rating(user1,element))
            rating2.append(get_rating(user2,element))

    return dot(rating1, rating2)/(norm(rating1)*norm(rating2))

### get K user nearest
def most_similar_user(user1, K_number_user, similarity_name):
  userid = ratings.userId.unique().tolist()

  if similarity_name == 'pearson':
    similarity_score =  [(pearson_correlation_score(user1, user_i), user_i) for user_i in userid if user_i != user1]

  if similarity_name == 'cosine':
    similarity_score =  [(distance_similarity_score(user1, user_i), user_i) for user_i in userid if user_i != user1]

  similarity_score.sort() # ascending
  similarity_score.reverse() # descending

  return similarity_score[:K_number_user]

# get items of user's history
def get_movieids_seen(userid):
  return (ratings.loc[(ratings.userId==userid), 'movieId'].tolist())
# Lấy ra tên của một bộ phim
def get_movie_name(movieid):
  return (movies.loc[(movies.movieId==movieid), 'title'].iloc[0])

# get recommendation for 1 user based on Aggregate weighted ratings
def rating_predict_based_on_user(userid, K_number_user, sim_name):
  total = {}
  sum_similarity = {}
  list_user_popular = most_similar_user(userid, K_number_user, sim_name)

  for similarityName, user_pop in list_user_popular: # lặp từng user trong list popular
    score = similarityName
    movieids = get_movieids_seen(user_pop)

    for movieid in movieids:
      if movieid not in get_movieids_seen(userid):
        if movieid not in total:
         total[movieid] = 0
         sum_similarity[movieid] = 0
        # print(f"sum_similarity[{movieid}]_1", sum_similarity[movieid])

        total[movieid] += get_rating(user_pop, movieid)*score
        sum_similarity[movieid] += score
        # print(f"sum_similarity[{movieid}]_2", sum_similarity[movieid])

    # calculate rating according to Aggregate weighted ratings
    list_ranking = []
    for userid,tot in total.items():
     if sum_similarity[userid] == 0:
       list_ranking.append((0,userid))
     else:
       rating = tot/(sum_similarity[userid])
       list_ranking.append((rating,userid))

  list_ranking = [(movieid, tot/sum_similarity[movieid]) for movieid, tot in total.items()]

  return list_ranking

### get name + the high rating predictions of topK=10 items
def get_recommendation_based_on_user(userid, K_number_user, similarity_name, topN = 10):

  list_ranking = rating_predict_based_on_user(userid, K_number_user, similarity_name)

  list_ranking.sort()
  list_ranking.reverse()


  return list_ranking[:topN]

# %% [markdown]
# ## Collaborative Filtering based on Item

# %%
### Pearson calculation
def pearson_correlation_score_Item(movie1, movie2):
  both_watch_count = [] 
  list_user_movie1 = ratings.loc[ratings.movieId==movie1, 'userId'].to_list()
  list_user_movie2 = ratings.loc[ratings.movieId==movie2, 'userId'].to_list()

  for userid in list_user_movie1:
    if userid in list_user_movie2:
      both_watch_count.append(userid)

  if len(both_watch_count)==0:
    return 0

  sum_rating_1 = sum([get_rating(i, movie1) for i in both_watch_count])
  avg_rating_1 = sum_rating_1/len(both_watch_count) 

  sum_rating_2 = sum([get_rating(i, movie2) for i in both_watch_count])
  avg_rating_2 = sum_rating_2/len(both_watch_count)

  TuSo = sum([(get_rating(i, movie1) - avg_rating_1)*(get_rating(i, movie2) - avg_rating_2) for i in both_watch_count])
  MauSo = sqrt(sum((get_rating(i, movie1) - avg_rating_1)**2 for i in both_watch_count))*sqrt(sum((get_rating(i, movie2) - avg_rating_2)**2 for i in both_watch_count))

  if MauSo==0:
    return 0

  return TuSo/MauSo


### Cosine calculation
def distance_similarity_score_Item(movie1,movie2):

    both_watch_count = 0
    for element in ratings.loc[ratings.movieId==movie1, 'userId'].tolist():
        if element in ratings.loc[ratings.movieId==movie2, 'userId'].tolist():
            both_watch_count += 1
    if both_watch_count == 0 :
        return 0

    rating1 = []
    rating2 = []
    for element in ratings.loc[ratings.movieId==movie1, 'userId'].tolist():
        if element in ratings.loc[ratings.movieId==movie2, 'userId'].tolist():
            rating1.append(get_rating(element,movie1))
            rating2.append(get_rating(element,movie2))

    return dot(rating1, rating2)/(norm(rating1)*norm(rating2))

### get K item nearest
def most_similar_movie(movie1, K_number_user, similarity_name):
  movieid = ratings.movieId.unique().tolist()
  # print(len(movieid))

  if similarity_name == 'pearson':
    similarity_score =  [(pearson_correlation_score_Item(movie1, movie_i), movie_i) for movie_i in movieid if movie_i != movie1]

  if similarity_name == 'cosine':
    similarity_score =  [(distance_similarity_score_Item(movie1, movie_i), movie_i) for movie_i in movieid if movie_i != movie1]

  similarity_score.sort() # ascending
  similarity_score.reverse() # descending

  return similarity_score[:K_number_user] # can change K user nearest


def get_userids(movieid):
  return (ratings.loc[(ratings.movieId==movieid), 'userId'].tolist())

# get recommendation for 1 user based on Aggregate weighted ratings
def rating_predict_based_on_item(movieid, K_number_item, sim_name):

  total = {}
  sum_similarity = {}
  list_movie_popular = most_similar_movie(movieid, K_number_item, sim_name)

  for similarityName, item_pop in list_movie_popular: # lặp từng user trong list popular
    score = similarityName
    userids = get_userids(item_pop)

    for userid in userids:
      if userid not in get_movieids_seen(movieid):
        if userid not in total:
         total[userid] = 0
         sum_similarity[userid] = 0

        total[userid] += get_rating(userid, item_pop)*score
        sum_similarity[userid] += score

    # calculate rating according to Aggregate weighted ratings
    list_ranking = []
    for movieid,tot in total.items():
     if sum_similarity[movieid] == 0:
       list_ranking.append((0,movieid))
     else:
       rating = tot/(sum_similarity[movieid])
       list_ranking.append((rating,movieid))

  list_ranking = [(userid, tot/sum_similarity[userid]) for userid, tot in total.items()]

  return list_ranking

### get name + the high rating predictions of topK=10 items
def get_recommendation_based_on_item(movieid, K_number_user, similarity_name, topN = 10):

  list_ranking = rating_predict_based_on_item(movieid, K_number_user, similarity_name)

  list_ranking.sort()
  list_ranking.reverse()

  return list_ranking[:topN]

# %% [markdown]
# ## Predicting on test set

# %% [markdown]
# ## User

# %%
# hàm dữ đoán trên tập test
def get_recommendation_on_test_user(test):
  X_test_pred = []
  X_test_userid = test['userId'].tolist()   #lấy ra danh sách các userID trong tập test
  X_test_movieID = test['movieId'].tolist()

  print("------Dự đoán cho tập test với {} điểm dữ liệu------".format(len(X_test_userid)))

  for i in range(len(X_test_userid)):        #lấy ra từng user
    list_R = get_recommendation_based_on_user(X_test_userid[i], 200, 'pearson', 10)    # lấy ra danh sách khuyến nghị dựa trên USER

    check = 0
    for j in list_R:
      if(X_test_movieID[i] == j[0]):     #j[1] là lấy movieID predict
        X_test_pred.append(j[1])
        check = 1
    if(check == 0):
      X_test_pred.append(0)
    print('----- Đang dự đoán cho dòng thứ {}'.format(i), 'là {}'.format(X_test_pred[i]))
  return X_test_pred

# %%
# hàm dữ đoán trên tập test
def get_recommendation_on_test_user_2(test):
  X_test_pred = []
  X_test_userid = test['userId'].tolist()   #lấy ra danh sách các userID trong tập test
  X_test_movieID = test['movieId'].tolist()

  print("------Dự đoán cho tập test với {} điểm dữ liệu------".format(len(X_test_userid)))

  for i in range(len(X_test_userid)):        #lấy ra từng user
    list_R = get_recommendation_based_on_user(X_test_userid[i], 200, 'cosine', 10)    # lấy ra danh sách khuyến nghị dựa trên USER

    check = 0
    for j in list_R:
      if(X_test_movieID[i] == j[0]):     #j[1] là lấy movieID predict
        X_test_pred.append(j[1])
        check = 1
    if(check == 0):
      X_test_pred.append(0)
    print('----- Đang dự đoán cho dòng thứ {}'.format(i), 'là {}'.format(X_test_pred[i]))
  return X_test_pred

# %%
start = time.time()
X_test_pred_user_pearson = get_recommendation_on_test_user(X_test)
X_test_pred_user_cosine = get_recommendation_on_test_user_2(X_test)
end = time.time()
print(f'Tổng thời gian dự đoán: {(end - start)/60} minutes')

# %%
X_test['X_test_pred_user_pearson'] = X_test_pred_user_pearson
X_test['X_test_pred_user_cosine'] = X_test_pred_user_cosine

# %%
X_test
# Out:
#        userId  movieId  rating     timestamp
# 1621     5932      307    10.0  1.458000e+09
# 2605     2542      412    10.0  1.485994e+09
# 4890      944      301     6.0  1.543363e+09
# 2040     5857      228     8.0  1.472083e+09
# 5399     5885      139     6.6  1.553904e+09
# ...       ...      ...     ...           ...
# 5365     5972      210     9.0  1.552867e+09
# 15687    5914      394     8.8  1.679098e+09
# 1896     5961      128     6.0  1.468109e+09
# 6694     6786       65     6.3  1.578442e+09
# 2045      934      549     8.5  1.472256e+09
#
# [959 rows x 4 columns]

# %% [markdown]
# ### Save prediction results

# %%
X_test.to_csv('X_test_UserKNN.csv')

# %% [markdown]
# ## Item

# %%
# Hàm dữ đoán trên tập test
def get_recommendation_on_test_item(test):
  X_test_pred = []
  X_test_userid = test['userId'].tolist()   #lấy ra danh sách các userID trong tập test
  X_test_movieID = test['movieId'].tolist()

  print("------Dự đoán cho tập test với {} điểm dữ liệu------".format(len(X_test_movieID)))

  for i in range(len(X_test_movieID)):        #lấy ra từng user
    list_R = get_recommendation_based_on_item(X_test_movieID[i], 100, 'pearson', 10)    # lấy ra danh sách khuyến nghị dựa trên USER

    check = 0
    for j in list_R:
      if(X_test_userid[i] == j[0]):     #j[1] là lấy movieID predict
        X_test_pred.append(j[1])
        check = 1
    if(check == 0):
      X_test_pred.append(0)
    print('----- Đang dự đoán cho dòng thứ {}'.format(i), 'là {}'.format(X_test_pred[i]))
  return X_test_pred

# %%
start = time.time()
X_test_pred_item_pearson = get_recommendation_on_test_item(X_test)
end = time.time()
print(f'Tổng thời gian dự đoán: {(end - start)/60} minutes')
# Out:
# ------Dự đoán cho tập test với 959 điểm dữ liệu------
# <ipython-input-31-245d4e089628>:99: RuntimeWarning: invalid value encountered in double_scalars
#   list_ranking = [(userid, tot/sum_similarity[userid]) for userid, tot in total.items()]
# ----- Đang dự đoán cho dòng thứ 0 là 7.6825269330104975
# ----- Đang dự đoán cho dòng thứ 1 là 7.29664344095203
# ----- Đang dự đoán cho dòng thứ 2 là 7.0
# ----- Đang dự đoán cho dòng thứ 3 là 6.31283513209117
# ----- Đang dự đoán cho dòng thứ 4 là 0
# ----- Đang dự đoán cho dòng thứ 5 là 7.397645858722833
# ----- Đang dự đoán cho dòng thứ 6 là 8.5
# ----- Đang dự đoán cho dòng thứ 7 là 4.0
# ----- Đang dự đoán cho dòng thứ 8 là 6.375123857048104
# ----- Đang dự đoán cho dòng thứ 9 là 9.0
# ----- Đang dự đoán cho dòng thứ 10 là 5.836958959306481
# ----- Đang dự đoán cho dòng thứ 11 là 7.0
# ----- Đang dự đoán cho dòng thứ 12 là 7.39352004450547
# ----- Đang dự đoán cho dòng thứ 13 là 6.397991744848035
# ----- Đang dự đoán cho dòng thứ 14 là 8.892558373830564
# ----- Đang dự đoán cho dòng thứ 15 là 6.0
# ----- Đang dự đoán cho dòng thứ 16 là 7.3890400363086846
# ----- Đang dự đoán cho dòng thứ 17 là nan
# ----- Đang dự đoán cho dòng thứ 18 là 7.569921391704029
# ----- Đang dự đoán cho dòng thứ 19 là 9.516154497425578
# ----- Đang dự đoán cho dòng thứ 20 là 6.0
# ----- Đang dự đoán cho dòng thứ 21 là 4.588563992446959
# ----- Đang dự đoán cho dòng thứ 22 là 6.000000000000001
# ----- Đang dự đoán cho dòng thứ 23 là 8.24956625092895
# ----- Đang dự đoán cho dòng thứ 24 là 4.0
# ----- Đang dự đoán cho dòng thứ 25 là 6.85611794949715
# ----- Đang dự đoán cho dòng thứ 26 là 5.999999999999999
# ----- Đang dự đoán cho dòng thứ 27 là 6.0
# ----- Đang dự đoán cho dòng thứ 28 là 3.0
# ----- Đang dự đoán cho dòng thứ 29 là 6.182278094149308
# ----- Đang dự đoán cho dòng thứ 30 là 6.323080432345946
# ----- Đang dự đoán cho dòng thứ 31 là 8.696523971358884
# ----- Đang dự đoán cho dòng thứ 32 là 7.0
# ----- Đang dự đoán cho dòng thứ 33 là 8.819842104000085
# ----- Đang dự đoán cho dòng thứ 34 là nan
# ----- Đang dự đoán cho dòng thứ 35 là 6.47687564214612
# ----- Đang dự đoán cho dòng thứ 36 là 5.33692403328089
# ----- Đang dự đoán cho dòng thứ 37 là 8.5
# ----- Đang dự đoán cho dòng thứ 38 là 1.0
# ----- Đang dự đoán cho dòng thứ 39 là 10.0
# ----- Đang dự đoán cho dòng thứ 40 là 8.523244079349672
# ----- Đang dự đoán cho dòng thứ 41 là 0
# ----- Đang dự đoán cho dòng thứ 42 là 5.784651347815786
# ----- Đang dự đoán cho dòng thứ 43 là 8.209088813222966
# ----- Đang dự đoán cho dòng thứ 44 là 7.202579145546794
# ----- Đang dự đoán cho dòng thứ 45 là 7.822627292703411
# ----- Đang dự đoán cho dòng thứ 46 là 5.5
# ----- Đang dự đoán cho dòng thứ 47 là 5.0
# ----- Đang dự đoán cho dòng thứ 48 là 7.182588914305486
# ----- Đang dự đoán cho dòng thứ 49 là 8.306244017985318
# ----- Đang dự đoán cho dòng thứ 50 là 7.0
# ----- Đang dự đoán cho dòng thứ 51 là 5.992644801950939
# ----- Đang dự đoán cho dòng thứ 52 là 5.999999999999999
# ----- Đang dự đoán cho dòng thứ 53 là 8.13547737552893
# ----- Đang dự đoán cho dòng thứ 54 là 8.5
# ----- Đang dự đoán cho dòng thứ 55 là 5.36265528557004
# ----- Đang dự đoán cho dòng thứ 56 là 7.0
# ----- Đang dự đoán cho dòng thứ 57 là 10.0
# ----- Đang dự đoán cho dòng thứ 58 là 9.7
# ----- Đang dự đoán cho dòng thứ 59 là 9.09059210896593
# ----- Đang dự đoán cho dòng thứ 60 là 6.148134538080399
# ----- Đang dự đoán cho dòng thứ 61 là nan
# ----- Đang dự đoán cho dòng thứ 62 là 6.852309321308261
# ----- Đang dự đoán cho dòng thứ 63 là 7.638712097559518
# ----- Đang dự đoán cho dòng thứ 64 là 9.4
# ----- Đang dự đoán cho dòng thứ 65 là 6.0618108406295415
# ----- Đang dự đoán cho dòng thứ 66 là 7.343243097179587
# ----- Đang dự đoán cho dòng thứ 67 là 8.261554579959773
# ----- Đang dự đoán cho dòng thứ 68 là 5.0
# ----- Đang dự đoán cho dòng thứ 69 là 8.529681984081865
# ----- Đang dự đoán cho dòng thứ 70 là 8.360673405394637
# ----- Đang dự đoán cho dòng thứ 71 là 7.666666666666667
# ----- Đang dự đoán cho dòng thứ 72 là nan
# ----- Đang dự đoán cho dòng thứ 73 là nan
# ----- Đang dự đoán cho dòng thứ 74 là 5.1
# ----- Đang dự đoán cho dòng thứ 75 là 6.711592980309264
# ----- Đang dự đoán cho dòng thứ 76 là 9.25
# ----- Đang dự đoán cho dòng thứ 77 là 6.931835094533158
# ----- Đang dự đoán cho dòng thứ 78 là nan
# ----- Đang dự đoán cho dòng thứ 79 là 9.378875320189653
# ----- Đang dự đoán cho dòng thứ 80 là 8.338461538461539
# ----- Đang dự đoán cho dòng thứ 81 là 8.294600905365378
# ----- Đang dự đoán cho dòng thứ 82 là 0
# ----- Đang dự đoán cho dòng thứ 83 là 8.0
# ----- Đang dự đoán cho dòng thứ 84 là nan
# ----- Đang dự đoán cho dòng thứ 85 là 5.5230150217722365
# ----- Đang dự đoán cho dòng thứ 86 là nan
# ----- Đang dự đoán cho dòng thứ 87 là 8.0
# ----- Đang dự đoán cho dòng thứ 88 là 8.537939455452541
# ----- Đang dự đoán cho dòng thứ 89 là 0
# ----- Đang dự đoán cho dòng thứ 90 là 7.0
# ----- Đang dự đoán cho dòng thứ 91 là 4.421777422596223
# ----- Đang dự đoán cho dòng thứ 92 là nan
# ----- Đang dự đoán cho dòng thứ 93 là 6.0
# ----- Đang dự đoán cho dòng thứ 94 là 7.804505422999319
# ----- Đang dự đoán cho dòng thứ 95 là 7.199371730665901
# ----- Đang dự đoán cho dòng thứ 96 là 8.849233775884848
# ----- Đang dự đoán cho dòng thứ 97 là 0
# ----- Đang dự đoán cho dòng thứ 98 là 8.075163768042549
# ----- Đang dự đoán cho dòng thứ 99 là 7.545220007400019
# ----- Đang dự đoán cho dòng thứ 100 là 9.0
# ----- Đang dự đoán cho dòng thứ 101 là 10.0
# ----- Đang dự đoán cho dòng thứ 102 là nan
# ----- Đang dự đoán cho dòng thứ 103 là 7.503449738859249
# ----- Đang dự đoán cho dòng thứ 104 là 8.5
# ----- Đang dự đoán cho dòng thứ 105 là 8.343079959877565
# ----- Đang dự đoán cho dòng thứ 106 là 6.073151374920108
# ----- Đang dự đoán cho dòng thứ 107 là 7.0
# ----- Đang dự đoán cho dòng thứ 108 là 7.56343264701909
# ----- Đang dự đoán cho dòng thứ 109 là 9.0
# ----- Đang dự đoán cho dòng thứ 110 là 6.3579487512169015
# ----- Đang dự đoán cho dòng thứ 111 là 6.252357450118609
# ----- Đang dự đoán cho dòng thứ 112 là 6.695887834008143
# ----- Đang dự đoán cho dòng thứ 113 là 8.652964935298339
# ----- Đang dự đoán cho dòng thứ 114 là 7.818241085664143
# ----- Đang dự đoán cho dòng thứ 115 là 0
# ----- Đang dự đoán cho dòng thứ 116 là 6.539194821073987
# ----- Đang dự đoán cho dòng thứ 117 là 8.84128770062494
# ----- Đang dự đoán cho dòng thứ 118 là 8.389435670042426
# ----- Đang dự đoán cho dòng thứ 119 là 5.966666666666668
# ----- Đang dự đoán cho dòng thứ 120 là nan
# ----- Đang dự đoán cho dòng thứ 121 là nan
# ----- Đang dự đoán cho dòng thứ 122 là 0
# ----- Đang dự đoán cho dòng thứ 123 là 7.000000000000001
# ----- Đang dự đoán cho dòng thứ 124 là nan
# ----- Đang dự đoán cho dòng thứ 125 là 8.619092194407438
# ----- Đang dự đoán cho dòng thứ 126 là nan
# ----- Đang dự đoán cho dòng thứ 127 là 10.0
# ----- Đang dự đoán cho dòng thứ 128 là 8.0
# ----- Đang dự đoán cho dòng thứ 129 là 0
# ----- Đang dự đoán cho dòng thứ 130 là 7.075176271286096
# ----- Đang dự đoán cho dòng thứ 131 là 10.0
# ----- Đang dự đoán cho dòng thứ 132 là 7.0
# ----- Đang dự đoán cho dòng thứ 133 là 6.34293899318148
# ----- Đang dự đoán cho dòng thứ 134 là 7.7
# ----- Đang dự đoán cho dòng thứ 135 là 10.0
# ----- Đang dự đoán cho dòng thứ 136 là 7.300000000000001
# ----- Đang dự đoán cho dòng thứ 137 là 5.580064227305744
# ----- Đang dự đoán cho dòng thứ 138 là 5.5573077164825175
# ----- Đang dự đoán cho dòng thứ 139 là 8.5
# ----- Đang dự đoán cho dòng thứ 140 là nan
# ----- Đang dự đoán cho dòng thứ 141 là 8.34884166159175
# ----- Đang dự đoán cho dòng thứ 142 là 0
# ----- Đang dự đoán cho dòng thứ 143 là 7.781894946643769
# ----- Đang dự đoán cho dòng thứ 144 là 4.0
# ----- Đang dự đoán cho dòng thứ 145 là 5.998178358158199
# ----- Đang dự đoán cho dòng thứ 146 là 7.0
# ----- Đang dự đoán cho dòng thứ 147 là 6.891514219312457
# ----- Đang dự đoán cho dòng thứ 148 là nan
# ----- Đang dự đoán cho dòng thứ 149 là 8.794366835600497
# ----- Đang dự đoán cho dòng thứ 150 là 4.999999999999999
# ----- Đang dự đoán cho dòng thứ 151 là 6.535825558193938
# ----- Đang dự đoán cho dòng thứ 152 là nan
# ----- Đang dự đoán cho dòng thứ 153 là 0
# ----- Đang dự đoán cho dòng thứ 154 là 9.0
# ----- Đang dự đoán cho dòng thứ 155 là 3.0
# ----- Đang dự đoán cho dòng thứ 156 là 5.729271388674419
# ----- Đang dự đoán cho dòng thứ 157 là 7.369779122575402
# ----- Đang dự đoán cho dòng thứ 158 là 7.000000000000001
# ----- Đang dự đoán cho dòng thứ 159 là 7.873007363675081
# ----- Đang dự đoán cho dòng thứ 160 là nan
# ----- Đang dự đoán cho dòng thứ 161 là 5.2
# ----- Đang dự đoán cho dòng thứ 162 là 8.092978459518442
# ----- Đang dự đoán cho dòng thứ 163 là 8.040305103978982
# ----- Đang dự đoán cho dòng thứ 164 là nan
# ----- Đang dự đoán cho dòng thứ 165 là 8.048162984152029
# ----- Đang dự đoán cho dòng thứ 166 là 0
# ----- Đang dự đoán cho dòng thứ 167 là 6.316126240597517
# ----- Đang dự đoán cho dòng thứ 168 là 8.166666666666666
# ----- Đang dự đoán cho dòng thứ 169 là 8.08517126366244
# ----- Đang dự đoán cho dòng thứ 170 là 7.0
# ----- Đang dự đoán cho dòng thứ 171 là 10.0
# ----- Đang dự đoán cho dòng thứ 172 là 6.870605791415916
# ----- Đang dự đoán cho dòng thứ 173 là 5.999999999999999
# ----- Đang dự đoán cho dòng thứ 174 là 9.030923141817429
# ----- Đang dự đoán cho dòng thứ 175 là 5.4
# ----- Đang dự đoán cho dòng thứ 176 là 8.0
# ----- Đang dự đoán cho dòng thứ 177 là 7.499999999999999
# ----- Đang dự đoán cho dòng thứ 178 là 6.75
# ----- Đang dự đoán cho dòng thứ 179 là 6.156044829287261
# ----- Đang dự đoán cho dòng thứ 180 là 5.4
# ----- Đang dự đoán cho dòng thứ 181 là 7.370306029856343
# ----- Đang dự đoán cho dòng thứ 182 là nan
# ----- Đang dự đoán cho dòng thứ 183 là 7.295197838156733
# ----- Đang dự đoán cho dòng thứ 184 là 9.160242871050642
# ----- Đang dự đoán cho dòng thứ 185 là 6.32013703685084
# ----- Đang dự đoán cho dòng thứ 186 là 7.25
# ----- Đang dự đoán cho dòng thứ 187 là 6.188507376509569
# ----- Đang dự đoán cho dòng thứ 188 là nan
# ----- Đang dự đoán cho dòng thứ 189 là 7.044500541403179
# ----- Đang dự đoán cho dòng thứ 190 là nan
# ----- Đang dự đoán cho dòng thứ 191 là 6.442845740780779
# ----- Đang dự đoán cho dòng thứ 192 là nan
# ----- Đang dự đoán cho dòng thứ 193 là nan
# ----- Đang dự đoán cho dòng thứ 194 là 8.4
# ----- Đang dự đoán cho dòng thứ 195 là 7.733333333333334
# ----- Đang dự đoán cho dòng thứ 196 là 6.0
# ----- Đang dự đoán cho dòng thứ 197 là 8.879150186638077
# ----- Đang dự đoán cho dòng thứ 198 là 5.450588459222348
# ----- Đang dự đoán cho dòng thứ 199 là 9.5
# ----- Đang dự đoán cho dòng thứ 200 là 8.46069581851844
# ----- Đang dự đoán cho dòng thứ 201 là 6.629908022984496
# ----- Đang dự đoán cho dòng thứ 202 là nan
# ----- Đang dự đoán cho dòng thứ 203 là 7.67489873434388
# ----- Đang dự đoán cho dòng thứ 204 là 9.500000000000002
# ----- Đang dự đoán cho dòng thứ 205 là nan
# ----- Đang dự đoán cho dòng thứ 206 là nan
# ----- Đang dự đoán cho dòng thứ 207 là 8.237649440352584
# ----- Đang dự đoán cho dòng thứ 208 là 8.366454908855886
# ----- Đang dự đoán cho dòng thứ 209 là 7.922072880621546
# ----- Đang dự đoán cho dòng thứ 210 là nan
# ----- Đang dự đoán cho dòng thứ 211 là nan
# ----- Đang dự đoán cho dòng thứ 212 là 6.599831800827587
# ----- Đang dự đoán cho dòng thứ 213 là 8.308173404500733
# ----- Đang dự đoán cho dòng thứ 214 là 0
# ----- Đang dự đoán cho dòng thứ 215 là 7.695534405643859
# ----- Đang dự đoán cho dòng thứ 216 là 9.55
# ----- Đang dự đoán cho dòng thứ 217 là 2.502053396173864
# ----- Đang dự đoán cho dòng thứ 218 là 6.6546038912267
# ----- Đang dự đoán cho dòng thứ 219 là 6.965669542057588
# ----- Đang dự đoán cho dòng thứ 220 là 9.0
# ----- Đang dự đoán cho dòng thứ 221 là 7.806215681572458
# ----- Đang dự đoán cho dòng thứ 222 là 7.220423991277972
# ----- Đang dự đoán cho dòng thứ 223 là nan
# ----- Đang dự đoán cho dòng thứ 224 là 10.0
# ----- Đang dự đoán cho dòng thứ 225 là 7.368419033093939
# ----- Đang dự đoán cho dòng thứ 226 là 6.446434831245892
# ----- Đang dự đoán cho dòng thứ 227 là 3.85
# ----- Đang dự đoán cho dòng thứ 228 là nan
# ----- Đang dự đoán cho dòng thứ 229 là 9.341011193445697
# ----- Đang dự đoán cho dòng thứ 230 là 7.89747911346479
# ----- Đang dự đoán cho dòng thứ 231 là 7.5313730334031135
# ----- Đang dự đoán cho dòng thứ 232 là 7.684597436229058
# ----- Đang dự đoán cho dòng thứ 233 là 8.0
# ----- Đang dự đoán cho dòng thứ 234 là 7.647460986949117
# ----- Đang dự đoán cho dòng thứ 235 là 5.615689542233769
# ----- Đang dự đoán cho dòng thứ 236 là 6.910547334360199
# ----- Đang dự đoán cho dòng thứ 237 là 9.445282560837814
# ----- Đang dự đoán cho dòng thứ 238 là 7.03773251041354
# ----- Đang dự đoán cho dòng thứ 239 là 7.0
# ----- Đang dự đoán cho dòng thứ 240 là nan
# ----- Đang dự đoán cho dòng thứ 241 là 0
# ----- Đang dự đoán cho dòng thứ 242 là 8.924999999999999
# ----- Đang dự đoán cho dòng thứ 243 là 8.5
# ----- Đang dự đoán cho dòng thứ 244 là 9.7
# ----- Đang dự đoán cho dòng thứ 245 là 10.0
# ----- Đang dự đoán cho dòng thứ 246 là 5.5
# ----- Đang dự đoán cho dòng thứ 247 là 7.337337718972346
# ----- Đang dự đoán cho dòng thứ 248 là 8.0
# ----- Đang dự đoán cho dòng thứ 249 là 5.8
# ----- Đang dự đoán cho dòng thứ 250 là 9.400000000000002
# ----- Đang dự đoán cho dòng thứ 251 là 9.85
# ----- Đang dự đoán cho dòng thứ 252 là 9.200317813234275
# ----- Đang dự đoán cho dòng thứ 253 là nan
# ----- Đang dự đoán cho dòng thứ 254 là 9.182855343469429
# ----- Đang dự đoán cho dòng thứ 255 là 6.701409839438799
# ----- Đang dự đoán cho dòng thứ 256 là 7.033333333333334
# ----- Đang dự đoán cho dòng thứ 257 là 7.466666666666666
# ----- Đang dự đoán cho dòng thứ 258 là 9.012499264104862
# ----- Đang dự đoán cho dòng thứ 259 là 5.714285714285714
# ----- Đang dự đoán cho dòng thứ 260 là 9.237970840839164
# ----- Đang dự đoán cho dòng thứ 261 là 6.207541113890648
# ----- Đang dự đoán cho dòng thứ 262 là nan
# ----- Đang dự đoán cho dòng thứ 263 là 6.320862370359676
# ----- Đang dự đoán cho dòng thứ 264 là 8.338386458026495
# ----- Đang dự đoán cho dòng thứ 265 là 8.143338030184909
# ----- Đang dự đoán cho dòng thứ 266 là 0
# ----- Đang dự đoán cho dòng thứ 267 là 6.500000000000001
# ----- Đang dự đoán cho dòng thứ 268 là 7.6164751063269565
# ----- Đang dự đoán cho dòng thứ 269 là 6.32350699800956
# ----- Đang dự đoán cho dòng thứ 270 là 7.0
# ----- Đang dự đoán cho dòng thứ 271 là 6.0
# ----- Đang dự đoán cho dòng thứ 272 là 8.166666666666666
# ----- Đang dự đoán cho dòng thứ 273 là 5.0
# ----- Đang dự đoán cho dòng thứ 274 là 6.500000000000001
# ----- Đang dự đoán cho dòng thứ 275 là 8.137906775535331
# ----- Đang dự đoán cho dòng thứ 276 là 8.200981459760381
# ----- Đang dự đoán cho dòng thứ 277 là 6.615312140504259
# ----- Đang dự đoán cho dòng thứ 278 là nan
# ----- Đang dự đoán cho dòng thứ 279 là 6.649006588560527
# ----- Đang dự đoán cho dòng thứ 280 là 7.967029737253171
# ----- Đang dự đoán cho dòng thứ 281 là 6.941279672256758
# ----- Đang dự đoán cho dòng thứ 282 là 8.409367018671814
# ----- Đang dự đoán cho dòng thứ 283 là 7.287753191142937
# ----- Đang dự đoán cho dòng thứ 284 là 7.302747279471594
# ----- Đang dự đoán cho dòng thứ 285 là nan
# ----- Đang dự đoán cho dòng thứ 286 là 1.0
# ----- Đang dự đoán cho dòng thứ 287 là 8.057928796990149
# ----- Đang dự đoán cho dòng thứ 288 là 6.0
# ----- Đang dự đoán cho dòng thứ 289 là 8.8
# ----- Đang dự đoán cho dòng thứ 290 là 0
# ----- Đang dự đoán cho dòng thứ 291 là 6.333483140509554
# ----- Đang dự đoán cho dòng thứ 292 là 0
# ----- Đang dự đoán cho dòng thứ 293 là 9.140631264154658
# ----- Đang dự đoán cho dòng thứ 294 là 7.589090636940804
# ----- Đang dự đoán cho dòng thứ 295 là 0
# ----- Đang dự đoán cho dòng thứ 296 là 8.486421109104892
# ----- Đang dự đoán cho dòng thứ 297 là 8.577135983167242
# ----- Đang dự đoán cho dòng thứ 298 là 0
# ----- Đang dự đoán cho dòng thứ 299 là nan
# ----- Đang dự đoán cho dòng thứ 300 là 5.4
# ----- Đang dự đoán cho dòng thứ 301 là 8.365561244268271
# ----- Đang dự đoán cho dòng thứ 302 là 7.0
# ----- Đang dự đoán cho dòng thứ 303 là 8.319933715218092
# ----- Đang dự đoán cho dòng thứ 304 là 6.837440699150611
# ----- Đang dự đoán cho dòng thứ 305 là 8.328703010950896
# ----- Đang dự đoán cho dòng thứ 306 là 6.489796017037104
# ----- Đang dự đoán cho dòng thứ 307 là 7.615043570734114
# ----- Đang dự đoán cho dòng thứ 308 là nan
# ----- Đang dự đoán cho dòng thứ 309 là 8.233333333333333
# ----- Đang dự đoán cho dòng thứ 310 là 8.626945053584631
# ----- Đang dự đoán cho dòng thứ 311 là 7.865848993425522
# ----- Đang dự đoán cho dòng thứ 312 là 4.0
# ----- Đang dự đoán cho dòng thứ 313 là 8.361462287826363
# ----- Đang dự đoán cho dòng thứ 314 là 9.7
# ----- Đang dự đoán cho dòng thứ 315 là 7.811803054180097
# ----- Đang dự đoán cho dòng thứ 316 là 6.000000000000001
# ----- Đang dự đoán cho dòng thứ 317 là 8.946753310924244
# ----- Đang dự đoán cho dòng thứ 318 là 7.7866246671764365
# ----- Đang dự đoán cho dòng thứ 319 là nan
# ----- Đang dự đoán cho dòng thứ 320 là nan
# ----- Đang dự đoán cho dòng thứ 321 là 6.999999999999999
# ----- Đang dự đoán cho dòng thứ 322 là 6.490381056766579
# ----- Đang dự đoán cho dòng thứ 323 là 9.025526615665475
# ----- Đang dự đoán cho dòng thứ 324 là 8.0
# ----- Đang dự đoán cho dòng thứ 325 là nan
# ----- Đang dự đoán cho dòng thứ 326 là 9.267533329642525
# ----- Đang dự đoán cho dòng thứ 327 là nan
# ----- Đang dự đoán cho dòng thứ 328 là 6.531154943679063
# ----- Đang dự đoán cho dòng thứ 329 là nan
# ----- Đang dự đoán cho dòng thứ 330 là 9.113301890766731
# ----- Đang dự đoán cho dòng thứ 331 là 4.242302408669149
# ----- Đang dự đoán cho dòng thứ 332 là 8.0
# ----- Đang dự đoán cho dòng thứ 333 là 0
# ----- Đang dự đoán cho dòng thứ 334 là 8.535338679958382
# ----- Đang dự đoán cho dòng thứ 335 là nan
# ----- Đang dự đoán cho dòng thứ 336 là 7.017335716201493
# ----- Đang dự đoán cho dòng thứ 337 là nan
# ----- Đang dự đoán cho dòng thứ 338 là 7.249066379614837
# ----- Đang dự đoán cho dòng thứ 339 là 9.044141295713512
# ----- Đang dự đoán cho dòng thứ 340 là nan
# ----- Đang dự đoán cho dòng thứ 341 là 4.8
# ----- Đang dự đoán cho dòng thứ 342 là nan
# ----- Đang dự đoán cho dòng thứ 343 là nan
# ----- Đang dự đoán cho dòng thứ 344 là 7.565633791401966
# ----- Đang dự đoán cho dòng thứ 345 là nan
# ----- Đang dự đoán cho dòng thứ 346 là 4.0
# ----- Đang dự đoán cho dòng thứ 347 là 9.861363085824323
# ----- Đang dự đoán cho dòng thứ 348 là 8.639412275866503
# ----- Đang dự đoán cho dòng thứ 349 là 6.305303733033788
# ----- Đang dự đoán cho dòng thứ 350 là 7.4771092376387385
# ----- Đang dự đoán cho dòng thứ 351 là 8.297239316957949
# ----- Đang dự đoán cho dòng thứ 352 là 7.410493476287096
# ----- Đang dự đoán cho dòng thứ 353 là 10.0
# ----- Đang dự đoán cho dòng thứ 354 là 8.323385277891978
# ----- Đang dự đoán cho dòng thứ 355 là 0
# ----- Đang dự đoán cho dòng thứ 356 là nan
# ----- Đang dự đoán cho dòng thứ 357 là 8.927168741656125
# ----- Đang dự đoán cho dòng thứ 358 là 9.30784985295603
# ----- Đang dự đoán cho dòng thứ 359 là nan
# ----- Đang dự đoán cho dòng thứ 360 là 8.87079938689647
# ----- Đang dự đoán cho dòng thứ 361 là nan
# ----- Đang dự đoán cho dòng thứ 362 là nan
# ----- Đang dự đoán cho dòng thứ 363 là 9.7
# ----- Đang dự đoán cho dòng thứ 364 là 7.0
# ----- Đang dự đoán cho dòng thứ 365 là 8.736664319194759
# ----- Đang dự đoán cho dòng thứ 366 là 7.063374138444384
# ----- Đang dự đoán cho dòng thứ 367 là 8.853803284501879
# ----- Đang dự đoán cho dòng thứ 368 là 6.772792206135786
# ----- Đang dự đoán cho dòng thứ 369 là 7.0150570565965955
# ----- Đang dự đoán cho dòng thứ 370 là 9.358654062412613
# ----- Đang dự đoán cho dòng thứ 371 là 6.360000000000001
# ----- Đang dự đoán cho dòng thứ 372 là 9.7
# ----- Đang dự đoán cho dòng thứ 373 là nan
# ----- Đang dự đoán cho dòng thứ 374 là 8.850960813832673
# ----- Đang dự đoán cho dòng thứ 375 là 7.3555970847090615
# ----- Đang dự đoán cho dòng thứ 376 là 0
# ----- Đang dự đoán cho dòng thứ 377 là 8.240382900915293
# ----- Đang dự đoán cho dòng thứ 378 là 9.744633640646027
# ----- Đang dự đoán cho dòng thứ 379 là 9.0
# ----- Đang dự đoán cho dòng thứ 380 là 5.999999999999999
# ----- Đang dự đoán cho dòng thứ 381 là 6.33354291122073
# ----- Đang dự đoán cho dòng thứ 382 là nan
# ----- Đang dự đoán cho dòng thứ 383 là 7.659636403481584
# ----- Đang dự đoán cho dòng thứ 384 là 6.720199221370399
# ----- Đang dự đoán cho dòng thứ 385 là 0
# ----- Đang dự đoán cho dòng thứ 386 là 9.530199429295104
# ----- Đang dự đoán cho dòng thứ 387 là 8.640257620728546
# ----- Đang dự đoán cho dòng thứ 388 là 7.044500541403179
# ----- Đang dự đoán cho dòng thứ 389 là 8.923593708906377
# ----- Đang dự đoán cho dòng thứ 390 là 8.362093281362402
# ----- Đang dự đoán cho dòng thứ 391 là 10.0
# ----- Đang dự đoán cho dòng thứ 392 là 0
# ----- Đang dự đoán cho dòng thứ 393 là 5.886235974604676
# ----- Đang dự đoán cho dòng thứ 394 là 0
# ----- Đang dự đoán cho dòng thứ 395 là 7.249999999999999
# ----- Đang dự đoán cho dòng thứ 396 là 6.618982320476146
# ----- Đang dự đoán cho dòng thứ 397 là 6.433994602996668
# ----- Đang dự đoán cho dòng thứ 398 là 8.870020385691966
# ----- Đang dự đoán cho dòng thứ 399 là 8.582124589382882
# ----- Đang dự đoán cho dòng thứ 400 là 9.5
# ----- Đang dự đoán cho dòng thứ 401 là 6.471164557068825
# ----- Đang dự đoán cho dòng thứ 402 là 8.064764638535957
# ----- Đang dự đoán cho dòng thứ 403 là nan
# ----- Đang dự đoán cho dòng thứ 404 là 6.57387035559689
# ----- Đang dự đoán cho dòng thứ 405 là 7.993162314400716
# ----- Đang dự đoán cho dòng thứ 406 là 6.0
# ----- Đang dự đoán cho dòng thứ 407 là 7.433842677917242
# ----- Đang dự đoán cho dòng thứ 408 là 8.155513627132908
# ----- Đang dự đoán cho dòng thứ 409 là 7.114683285146923
# ----- Đang dự đoán cho dòng thứ 410 là 9.0
# ----- Đang dự đoán cho dòng thứ 411 là 6.7
# ----- Đang dự đoán cho dòng thứ 412 là 6.0
# ----- Đang dự đoán cho dòng thứ 413 là 7.85
# ----- Đang dự đoán cho dòng thứ 414 là 5.007237102605743
# ----- Đang dự đoán cho dòng thứ 415 là 5.499999999999999
# ----- Đang dự đoán cho dòng thứ 416 là 6.699722868983035
# ----- Đang dự đoán cho dòng thứ 417 là 6.190040404440074
# ----- Đang dự đoán cho dòng thứ 418 là 6.857435781019765
# ----- Đang dự đoán cho dòng thứ 419 là 9.7
# ----- Đang dự đoán cho dòng thứ 420 là 7.3
# ----- Đang dự đoán cho dòng thứ 421 là 6.265761222559443
# ----- Đang dự đoán cho dòng thứ 422 là 8.8
# ----- Đang dự đoán cho dòng thứ 423 là nan
# ----- Đang dự đoán cho dòng thứ 424 là 8.0
# ----- Đang dự đoán cho dòng thứ 425 là 6.7879901992862335
# ----- Đang dự đoán cho dòng thứ 426 là 7.5908011094025705
# ----- Đang dự đoán cho dòng thứ 427 là 7.258617527152152
# ----- Đang dự đoán cho dòng thứ 428 là 6.0
# ----- Đang dự đoán cho dòng thứ 429 là 9.037037037037038
# ----- Đang dự đoán cho dòng thứ 430 là 8.775175752209165
# ----- Đang dự đoán cho dòng thứ 431 là 8.5
# ----- Đang dự đoán cho dòng thứ 432 là 7.0
# ----- Đang dự đoán cho dòng thứ 433 là 5.2
# ----- Đang dự đoán cho dòng thứ 434 là 6.865221638199949
# ----- Đang dự đoán cho dòng thứ 435 là 7.856982458427366
# ----- Đang dự đoán cho dòng thứ 436 là 7.983388180881348
# ----- Đang dự đoán cho dòng thứ 437 là 7.249999999999998
# ----- Đang dự đoán cho dòng thứ 438 là nan
# ----- Đang dự đoán cho dòng thứ 439 là 9.5
# ----- Đang dự đoán cho dòng thứ 440 là 0
# ----- Đang dự đoán cho dòng thứ 441 là 5.8859595606338795
# ----- Đang dự đoán cho dòng thứ 442 là 8.451768605198527
# ----- Đang dự đoán cho dòng thứ 443 là 7.730803363079218
# ----- Đang dự đoán cho dòng thứ 444 là 8.738690109376916
# ----- Đang dự đoán cho dòng thứ 445 là 8.131494683928835
# ----- Đang dự đoán cho dòng thứ 446 là nan
# ----- Đang dự đoán cho dòng thứ 447 là 0
# ----- Đang dự đoán cho dòng thứ 448 là 1.0
# ----- Đang dự đoán cho dòng thứ 449 là 7.50454583026496
# ----- Đang dự đoán cho dòng thứ 450 là nan
# ----- Đang dự đoán cho dòng thứ 451 là 5.783969954300348
# ----- Đang dự đoán cho dòng thứ 452 là 6.958032862383763
# ----- Đang dự đoán cho dòng thứ 453 là 9.7
# ----- Đang dự đoán cho dòng thứ 454 là 7.175066793432228
# ----- Đang dự đoán cho dòng thứ 455 là 5.666666666666667
# ----- Đang dự đoán cho dòng thứ 456 là 0
# ----- Đang dự đoán cho dòng thứ 457 là 7.500000000000001
# ----- Đang dự đoán cho dòng thứ 458 là 9.7
# ----- Đang dự đoán cho dòng thứ 459 là 5.1
# ----- Đang dự đoán cho dòng thứ 460 là 0
# ----- Đang dự đoán cho dòng thứ 461 là 7.773831285321392
# ----- Đang dự đoán cho dòng thứ 462 là 8.361180212301981
# ----- Đang dự đoán cho dòng thứ 463 là 8.009401561181855
# ----- Đang dự đoán cho dòng thứ 464 là 7.107680189156691
# ----- Đang dự đoán cho dòng thứ 465 là 7.703947540563103
# ----- Đang dự đoán cho dòng thứ 466 là 0
# ----- Đang dự đoán cho dòng thứ 467 là 7.566723432363206
# ----- Đang dự đoán cho dòng thứ 468 là 7.974459288619052
# ----- Đang dự đoán cho dòng thứ 469 là 8.185315758139705
# ----- Đang dự đoán cho dòng thứ 470 là 8.1360337052493
# ----- Đang dự đoán cho dòng thứ 471 là 8.5
# ----- Đang dự đoán cho dòng thứ 472 là 4.0
# ----- Đang dự đoán cho dòng thứ 473 là 10.0
# ----- Đang dự đoán cho dòng thứ 474 là 6.0
# ----- Đang dự đoán cho dòng thứ 475 là 8.830015848218778
# ----- Đang dự đoán cho dòng thứ 476 là 8.845901224596792
# ----- Đang dự đoán cho dòng thứ 477 là 8.0
# ----- Đang dự đoán cho dòng thứ 478 là 6.73302983765936
# ----- Đang dự đoán cho dòng thứ 479 là 8.442760922929446
# ----- Đang dự đoán cho dòng thứ 480 là 7.86682107002134
# ----- Đang dự đoán cho dòng thứ 481 là 7.1748257094642645
# ----- Đang dự đoán cho dòng thứ 482 là 6.346636876645446
# ----- Đang dự đoán cho dòng thứ 483 là 9.096231948169313
# ----- Đang dự đoán cho dòng thứ 484 là 6.977441945932181
# ----- Đang dự đoán cho dòng thứ 485 là 7.234621249194161
# ----- Đang dự đoán cho dòng thứ 486 là 8.832188209008319
# ----- Đang dự đoán cho dòng thứ 487 là nan
# ----- Đang dự đoán cho dòng thứ 488 là 6.0
# ----- Đang dự đoán cho dòng thứ 489 là 10.0
# ----- Đang dự đoán cho dòng thứ 490 là 10.0
# ----- Đang dự đoán cho dòng thứ 491 là 6.890593055466801
# ----- Đang dự đoán cho dòng thứ 492 là 7.31325260038592
# ----- Đang dự đoán cho dòng thứ 493 là 7.0
# ----- Đang dự đoán cho dòng thứ 494 là 9.4
# ----- Đang dự đoán cho dòng thứ 495 là 8.206470750733905
# ----- Đang dự đoán cho dòng thứ 496 là nan
# ----- Đang dự đoán cho dòng thứ 497 là 7.703305821310904
# ----- Đang dự đoán cho dòng thứ 498 là 6.1000000000000005
# ----- Đang dự đoán cho dòng thứ 499 là 4.0
# ----- Đang dự đoán cho dòng thứ 500 là 10.0
# ----- Đang dự đoán cho dòng thứ 501 là nan
# ----- Đang dự đoán cho dòng thứ 502 là 8.56605001277106
# ----- Đang dự đoán cho dòng thứ 503 là nan
# ----- Đang dự đoán cho dòng thứ 504 là 9.0
# ----- Đang dự đoán cho dòng thứ 505 là 5.1
# ----- Đang dự đoán cho dòng thứ 506 là 8.409870589394078
# ----- Đang dự đoán cho dòng thứ 507 là nan
# ----- Đang dự đoán cho dòng thứ 508 là 6.483693692330897
# ----- Đang dự đoán cho dòng thứ 509 là 0
# ----- Đang dự đoán cho dòng thứ 510 là 9.0
# ----- Đang dự đoán cho dòng thứ 511 là 7.831875244889531
# ----- Đang dự đoán cho dòng thứ 512 là 8.7
# ----- Đang dự đoán cho dòng thứ 513 là 7.556004831541004
# ----- Đang dự đoán cho dòng thứ 514 là nan
# ----- Đang dự đoán cho dòng thứ 515 là 6.000000000000001
# ----- Đang dự đoán cho dòng thứ 516 là 8.61224647950896
# ----- Đang dự đoán cho dòng thứ 517 là 8.7
# ----- Đang dự đoán cho dòng thứ 518 là 10.0
# ----- Đang dự đoán cho dòng thứ 519 là 5.9141276988835925
# ----- Đang dự đoán cho dòng thứ 520 là 0
# ----- Đang dự đoán cho dòng thứ 521 là nan
# ----- Đang dự đoán cho dòng thứ 522 là 6.023529411764706
# ----- Đang dự đoán cho dòng thứ 523 là nan
# ----- Đang dự đoán cho dòng thứ 524 là 7.1509547895471135
# ----- Đang dự đoán cho dòng thứ 525 là 6.268493653415095
# ----- Đang dự đoán cho dòng thứ 526 là 6.5
# ----- Đang dự đoán cho dòng thứ 527 là 8.56358721574224
# ----- Đang dự đoán cho dòng thứ 528 là 7.897187766781403
# ----- Đang dự đoán cho dòng thứ 529 là 8.346391212745457
# ----- Đang dự đoán cho dòng thứ 530 là nan
# ----- Đang dự đoán cho dòng thứ 531 là 7.786172007871286
# ----- Đang dự đoán cho dòng thứ 532 là 9.4
# ----- Đang dự đoán cho dòng thứ 533 là 0
# ----- Đang dự đoán cho dòng thứ 534 là 8.699038677214395
# ----- Đang dự đoán cho dòng thứ 535 là 1.0
# ----- Đang dự đoán cho dòng thứ 536 là 9.0
# ----- Đang dự đoán cho dòng thứ 537 là 9.561989214760782
# ----- Đang dự đoán cho dòng thứ 538 là 9.833572107705436
# ----- Đang dự đoán cho dòng thứ 539 là 10.0
# ----- Đang dự đoán cho dòng thứ 540 là nan
# ----- Đang dự đoán cho dòng thứ 541 là nan
# ----- Đang dự đoán cho dòng thứ 542 là 7.7
# ----- Đang dự đoán cho dòng thứ 543 là 9.0
# ----- Đang dự đoán cho dòng thứ 544 là 8.0
# ----- Đang dự đoán cho dòng thứ 545 là 6.0
# ----- Đang dự đoán cho dòng thứ 546 là 8.652593817957024
# ----- Đang dự đoán cho dòng thứ 547 là 8.65
# ----- Đang dự đoán cho dòng thứ 548 là 8.11317837621472
# ----- Đang dự đoán cho dòng thứ 549 là 7.297612719655326
# ----- Đang dự đoán cho dòng thứ 550 là 9.2190213314226
# ----- Đang dự đoán cho dòng thứ 551 là 8.850421886291898
# ----- Đang dự đoán cho dòng thứ 552 là 8.928571428571427
# ----- Đang dự đoán cho dòng thứ 553 là 0
# ----- Đang dự đoán cho dòng thứ 554 là 8.5
# ----- Đang dự đoán cho dòng thứ 555 là 8.020876668483298
# ----- Đang dự đoán cho dòng thứ 556 là 8.463785920823174
# ----- Đang dự đoán cho dòng thứ 557 là 0
# ----- Đang dự đoán cho dòng thứ 558 là 8.739401731550858
# ----- Đang dự đoán cho dòng thứ 559 là nan
# ----- Đang dự đoán cho dòng thứ 560 là 8.10455493956973
# ----- Đang dự đoán cho dòng thứ 561 là 9.7
# ----- Đang dự đoán cho dòng thứ 562 là 6.5
# ----- Đang dự đoán cho dòng thứ 563 là 6.8
# ----- Đang dự đoán cho dòng thứ 564 là 7.207947614557663
# ----- Đang dự đoán cho dòng thứ 565 là 8.395516027667936
# ----- Đang dự đoán cho dòng thứ 566 là 9.0
# ----- Đang dự đoán cho dòng thứ 567 là 10.0
# ----- Đang dự đoán cho dòng thứ 568 là 7.670948283025586
# ----- Đang dự đoán cho dòng thứ 569 là nan
# ----- Đang dự đoán cho dòng thứ 570 là 7.0935887006261185
# ----- Đang dự đoán cho dòng thứ 571 là 8.657343020693531
# ----- Đang dự đoán cho dòng thứ 572 là nan
# ----- Đang dự đoán cho dòng thứ 573 là 9.58408390155839
# ----- Đang dự đoán cho dòng thứ 574 là 9.7
# ----- Đang dự đoán cho dòng thứ 575 là 8.52113727835042
# ----- Đang dự đoán cho dòng thứ 576 là 6.6
# ----- Đang dự đoán cho dòng thứ 577 là 5.556996371550079
# ----- Đang dự đoán cho dòng thứ 578 là 6.8847646314082365
# ----- Đang dự đoán cho dòng thứ 579 là nan
# ----- Đang dự đoán cho dòng thứ 580 là 0
# ----- Đang dự đoán cho dòng thứ 581 là 7.014401940443793
# ----- Đang dự đoán cho dòng thứ 582 là 7.242685378482381
# ----- Đang dự đoán cho dòng thứ 583 là 8.493450315097386
# ----- Đang dự đoán cho dòng thứ 584 là nan
# ----- Đang dự đoán cho dòng thứ 585 là 8.42109682267465
# ----- Đang dự đoán cho dòng thứ 586 là 0
# ----- Đang dự đoán cho dòng thứ 587 là 8.42186466050375
# ----- Đang dự đoán cho dòng thứ 588 là nan
# ----- Đang dự đoán cho dòng thứ 589 là nan
# ----- Đang dự đoán cho dòng thứ 590 là 8.88871879579762
# ----- Đang dự đoán cho dòng thứ 591 là nan
# ----- Đang dự đoán cho dòng thứ 592 là 7.659180121896888
# ----- Đang dự đoán cho dòng thứ 593 là 9.101086785570748
# ----- Đang dự đoán cho dòng thứ 594 là nan
# ----- Đang dự đoán cho dòng thứ 595 là 7.69707889836304
# ----- Đang dự đoán cho dòng thứ 596 là nan
# ----- Đang dự đoán cho dòng thứ 597 là 9.666666666666666
# ----- Đang dự đoán cho dòng thứ 598 là 5.48287454325805
# ----- Đang dự đoán cho dòng thứ 599 là 6.554161797933425
# ----- Đang dự đoán cho dòng thứ 600 là 8.138710518278792
# ----- Đang dự đoán cho dòng thứ 601 là 0
# ----- Đang dự đoán cho dòng thứ 602 là nan
# ----- Đang dự đoán cho dòng thứ 603 là 6.0
# ----- Đang dự đoán cho dòng thứ 604 là 6.952682823214835
# ----- Đang dự đoán cho dòng thứ 605 là 9.700318340723236
# ----- Đang dự đoán cho dòng thứ 606 là 7.422672942810598
# ----- Đang dự đoán cho dòng thứ 607 là 6.530856460267449
# ----- Đang dự đoán cho dòng thứ 608 là 7.278223512226923
# ----- Đang dự đoán cho dòng thứ 609 là nan
# ----- Đang dự đoán cho dòng thứ 610 là 6.823521926882982
# ----- Đang dự đoán cho dòng thứ 611 là nan
# ----- Đang dự đoán cho dòng thứ 612 là 7.553107541586619
# ----- Đang dự đoán cho dòng thứ 613 là 0
# ----- Đang dự đoán cho dòng thứ 614 là 3.001558442504705
# ----- Đang dự đoán cho dòng thứ 615 là 7.2
# ----- Đang dự đoán cho dòng thứ 616 là 5.6
# ----- Đang dự đoán cho dòng thứ 617 là 7.8952729029415245
# ----- Đang dự đoán cho dòng thứ 618 là 5.7
# ----- Đang dự đoán cho dòng thứ 619 là 7.0
# ----- Đang dự đoán cho dòng thứ 620 là 8.66961014187634
# ----- Đang dự đoán cho dòng thứ 621 là 8.881818181818181
# ----- Đang dự đoán cho dòng thứ 622 là 6.477882035304498
# ----- Đang dự đoán cho dòng thứ 623 là 7.63769537083982
# ----- Đang dự đoán cho dòng thứ 624 là 6.705316294615978
# ----- Đang dự đoán cho dòng thứ 625 là 7.406616099457966
# ----- Đang dự đoán cho dòng thứ 626 là 8.549340682374977
# ----- Đang dự đoán cho dòng thứ 627 là 5.886235974604676
# ----- Đang dự đoán cho dòng thứ 628 là 8.700919366536567
# ----- Đang dự đoán cho dòng thứ 629 là 9.070149050844623
# ----- Đang dự đoán cho dòng thứ 630 là 8.21653888528972
# ----- Đang dự đoán cho dòng thứ 631 là 6.1380221275647235
# ----- Đang dự đoán cho dòng thứ 632 là 8.112585506647909
# ----- Đang dự đoán cho dòng thứ 633 là nan
# ----- Đang dự đoán cho dòng thứ 634 là 8.0
# ----- Đang dự đoán cho dòng thứ 635 là 7.53070715820064
# ----- Đang dự đoán cho dòng thứ 636 là 7.834972811060522
# ----- Đang dự đoán cho dòng thứ 637 là 6.762737016116019
# ----- Đang dự đoán cho dòng thứ 638 là 6.937352192084883
# ----- Đang dự đoán cho dòng thứ 639 là 8.253882877382198
# ----- Đang dự đoán cho dòng thứ 640 là 7.040360535220935
# ----- Đang dự đoán cho dòng thứ 641 là nan
# ----- Đang dự đoán cho dòng thứ 642 là 0
# ----- Đang dự đoán cho dòng thứ 643 là nan
# ----- Đang dự đoán cho dòng thứ 644 là nan
# ----- Đang dự đoán cho dòng thứ 645 là 5.97167540709727
# ----- Đang dự đoán cho dòng thứ 646 là 9.436102606293232
# ----- Đang dự đoán cho dòng thứ 647 là 6.276470588235293
# ----- Đang dự đoán cho dòng thứ 648 là 6.3484309236593335
# ----- Đang dự đoán cho dòng thứ 649 là nan
# ----- Đang dự đoán cho dòng thứ 650 là 0
# ----- Đang dự đoán cho dòng thứ 651 là 7.489781275743216
# ----- Đang dự đoán cho dòng thứ 652 là 9.5
# ----- Đang dự đoán cho dòng thứ 653 là 6.389878973748922
# ----- Đang dự đoán cho dòng thứ 654 là 6.006189348574035
# ----- Đang dự đoán cho dòng thứ 655 là 10.0
# ----- Đang dự đoán cho dòng thứ 656 là 7.016702493223549
# ----- Đang dự đoán cho dòng thứ 657 là 0
# ----- Đang dự đoán cho dòng thứ 658 là 3.5
# ----- Đang dự đoán cho dòng thứ 659 là 5.855557281986462
# ----- Đang dự đoán cho dòng thứ 660 là 6.377417233059399
# ----- Đang dự đoán cho dòng thứ 661 là 7.795848314834407
# ----- Đang dự đoán cho dòng thứ 662 là 8.967001256895621
# ----- Đang dự đoán cho dòng thứ 663 là 9.115696269763273
# ----- Đang dự đoán cho dòng thứ 664 là nan
# ----- Đang dự đoán cho dòng thứ 665 là 7.033333333333334
# ----- Đang dự đoán cho dòng thứ 666 là 6.127947877547518
# ----- Đang dự đoán cho dòng thứ 667 là 7.759452395550991
# ----- Đang dự đoán cho dòng thứ 668 là 7.5
# ----- Đang dự đoán cho dòng thứ 669 là 7.802007607546212
# ----- Đang dự đoán cho dòng thứ 670 là 7.0
# ----- Đang dự đoán cho dòng thứ 671 là 6.84767256371299
# ----- Đang dự đoán cho dòng thứ 672 là 6.36
# ----- Đang dự đoán cho dòng thứ 673 là 6.85611794949715
# ----- Đang dự đoán cho dòng thứ 674 là 9.27464860225713
# ----- Đang dự đoán cho dòng thứ 675 là nan
# ----- Đang dự đoán cho dòng thứ 676 là 6.0
# ----- Đang dự đoán cho dòng thứ 677 là 7.696010279361329
# ----- Đang dự đoán cho dòng thứ 678 là nan
# ----- Đang dự đoán cho dòng thứ 679 là 8.958705421019864
# ----- Đang dự đoán cho dòng thứ 680 là 8.731561372315912
# ----- Đang dự đoán cho dòng thứ 681 là 6.306391342283836
# ----- Đang dự đoán cho dòng thứ 682 là 8.21295206172429
# ----- Đang dự đoán cho dòng thứ 683 là 7.107844795180099
# ----- Đang dự đoán cho dòng thứ 684 là 8.293435150539935
# ----- Đang dự đoán cho dòng thứ 685 là 9.098882670977105
# ----- Đang dự đoán cho dòng thứ 686 là 7.336558860633309
# ----- Đang dự đoán cho dòng thứ 687 là 7.242637838522302
# ----- Đang dự đoán cho dòng thứ 688 là 8.34838492305897
# ----- Đang dự đoán cho dòng thứ 689 là 0
# ----- Đang dự đoán cho dòng thứ 690 là 7.474915778265172
# ----- Đang dự đoán cho dòng thứ 691 là 7.592641502196873
# ----- Đang dự đoán cho dòng thứ 692 là 9.201572996545702
# ----- Đang dự đoán cho dòng thứ 693 là 9.192382858937435
# ----- Đang dự đoán cho dòng thứ 694 là 9.0
# ----- Đang dự đoán cho dòng thứ 695 là 7.753960662905632
# ----- Đang dự đoán cho dòng thứ 696 là 9.5
# ----- Đang dự đoán cho dòng thứ 697 là 8.774868113369337
# ----- Đang dự đoán cho dòng thứ 698 là 8.417113890206961
# ----- Đang dự đoán cho dòng thứ 699 là 8.77805051930093
# ----- Đang dự đoán cho dòng thứ 700 là 6.011578006369363
# ----- Đang dự đoán cho dòng thứ 701 là 6.428078769547152
# ----- Đang dự đoán cho dòng thứ 702 là nan
# ----- Đang dự đoán cho dòng thứ 703 là 8.463116358416842
# ----- Đang dự đoán cho dòng thứ 704 là 9.577047738042518
# ----- Đang dự đoán cho dòng thứ 705 là 6.90035632334813
# ----- Đang dự đoán cho dòng thứ 706 là 7.6566264065704654
# ----- Đang dự đoán cho dòng thứ 707 là 8.509708357264286
# ----- Đang dự đoán cho dòng thứ 708 là 6.215192727260461
# ----- Đang dự đoán cho dòng thứ 709 là nan
# ----- Đang dự đoán cho dòng thứ 710 là nan
# ----- Đang dự đoán cho dòng thứ 711 là nan
# ----- Đang dự đoán cho dòng thứ 712 là 9.25691181880832
# ----- Đang dự đoán cho dòng thứ 713 là 0
# ----- Đang dự đoán cho dòng thứ 714 là 8.0
# ----- Đang dự đoán cho dòng thứ 715 là 10.0
# ----- Đang dự đoán cho dòng thứ 716 là nan
# ----- Đang dự đoán cho dòng thứ 717 là 6.909111307466005
# ----- Đang dự đoán cho dòng thứ 718 là 7.000000000000001
# ----- Đang dự đoán cho dòng thứ 719 là 7.290811719250489
# ----- Đang dự đoán cho dòng thứ 720 là 8.52145413243066
# ----- Đang dự đoán cho dòng thứ 721 là 8.530962974688164
# ----- Đang dự đoán cho dòng thứ 722 là 7.5
# ----- Đang dự đoán cho dòng thứ 723 là 0
# ----- Đang dự đoán cho dòng thứ 724 là 7.020772638014966
# ----- Đang dự đoán cho dòng thứ 725 là nan
# ----- Đang dự đoán cho dòng thứ 726 là 8.975799199952426
# ----- Đang dự đoán cho dòng thứ 727 là 8.580534444270823
# ----- Đang dự đoán cho dòng thứ 728 là 9.5
# ----- Đang dự đoán cho dòng thứ 729 là 10.0
# ----- Đang dự đoán cho dòng thứ 730 là 8.0
# ----- Đang dự đoán cho dòng thứ 731 là 6.0
# ----- Đang dự đoán cho dòng thứ 732 là 5.756622566682868
# ----- Đang dự đoán cho dòng thứ 733 là nan
# ----- Đang dự đoán cho dòng thứ 734 là 6.4037600613957055
# ----- Đang dự đoán cho dòng thứ 735 là 6.84767256371299
# ----- Đang dự đoán cho dòng thứ 736 là 5.999999999999999
# ----- Đang dự đoán cho dòng thứ 737 là 8.562553710392256
# ----- Đang dự đoán cho dòng thứ 738 là 9.54758150648961
# ----- Đang dự đoán cho dòng thứ 739 là 8.68551752428158
# ----- Đang dự đoán cho dòng thứ 740 là 1.0
# ----- Đang dự đoán cho dòng thứ 741 là nan
# ----- Đang dự đoán cho dòng thứ 742 là 8.150668838463124
# ----- Đang dự đoán cho dòng thứ 743 là nan
# ----- Đang dự đoán cho dòng thứ 744 là nan
# ----- Đang dự đoán cho dòng thứ 745 là 8.197001415429485
# ----- Đang dự đoán cho dòng thứ 746 là 0
# ----- Đang dự đoán cho dòng thứ 747 là 4.0
# ----- Đang dự đoán cho dòng thứ 748 là 8.442002539933258
# ----- Đang dự đoán cho dòng thứ 749 là 6.0
# ----- Đang dự đoán cho dòng thứ 750 là 8.328306131607944
# ----- Đang dự đoán cho dòng thứ 751 là 6.272962831729735
# ----- Đang dự đoán cho dòng thứ 752 là 7.370306029856343
# ----- Đang dự đoán cho dòng thứ 753 là 6.889125692030581
# ----- Đang dự đoán cho dòng thứ 754 là 9.0
# ----- Đang dự đoán cho dòng thứ 755 là 7.5
# ----- Đang dự đoán cho dòng thứ 756 là nan
# ----- Đang dự đoán cho dòng thứ 757 là nan
# ----- Đang dự đoán cho dòng thứ 758 là 7.000000000000001
# ----- Đang dự đoán cho dòng thứ 759 là 7.442276830889573
# ----- Đang dự đoán cho dòng thứ 760 là 0
# ----- Đang dự đoán cho dòng thứ 761 là 5.436116865063836
# ----- Đang dự đoán cho dòng thứ 762 là 8.213335404457089
# ----- Đang dự đoán cho dòng thứ 763 là 8.0
# ----- Đang dự đoán cho dòng thứ 764 là 6.2
# ----- Đang dự đoán cho dòng thứ 765 là 7.304556808777737
# ----- Đang dự đoán cho dòng thứ 766 là 10.0
# ----- Đang dự đoán cho dòng thứ 767 là 8.746622524927655
# ----- Đang dự đoán cho dòng thứ 768 là 7.0
# ----- Đang dự đoán cho dòng thứ 769 là 9.7
# ----- Đang dự đoán cho dòng thứ 770 là nan
# ----- Đang dự đoán cho dòng thứ 771 là 7.0
# ----- Đang dự đoán cho dòng thứ 772 là 5.1255984894184
# ----- Đang dự đoán cho dòng thứ 773 là 8.426048498133929
# ----- Đang dự đoán cho dòng thứ 774 là 9.637478085701186
# ----- Đang dự đoán cho dòng thứ 775 là 6.64319550417745
# ----- Đang dự đoán cho dòng thứ 776 là 9.300616044463961
# ----- Đang dự đoán cho dòng thứ 777 là 8.901263902304338
# ----- Đang dự đoán cho dòng thứ 778 là 8.237488685095165
# ----- Đang dự đoán cho dòng thứ 779 là 8.958705421019864
# ----- Đang dự đoán cho dòng thứ 780 là 8.894050868518304
# ----- Đang dự đoán cho dòng thứ 781 là nan
# ----- Đang dự đoán cho dòng thứ 782 là nan
# ----- Đang dự đoán cho dòng thứ 783 là 7.008554098002711
# ----- Đang dự đoán cho dòng thứ 784 là 5.299529515384252
# ----- Đang dự đoán cho dòng thứ 785 là nan
# ----- Đang dự đoán cho dòng thứ 786 là 7.5
# ----- Đang dự đoán cho dòng thứ 787 là 9.8
# ----- Đang dự đoán cho dòng thứ 788 là 8.80208077231355
# ----- Đang dự đoán cho dòng thứ 789 là 9.351713900991946
# ----- Đang dự đoán cho dòng thứ 790 là 5.846773386792174
# ----- Đang dự đoán cho dòng thứ 791 là nan
# ----- Đang dự đoán cho dòng thứ 792 là 7.0
# ----- Đang dự đoán cho dòng thứ 793 là 0
# ----- Đang dự đoán cho dòng thứ 794 là 0
# ----- Đang dự đoán cho dòng thứ 795 là 0
# ----- Đang dự đoán cho dòng thứ 796 là nan
# ----- Đang dự đoán cho dòng thứ 797 là 5.46211726221277
# ----- Đang dự đoán cho dòng thứ 798 là 8.040070889527476
# ----- Đang dự đoán cho dòng thứ 799 là 8.046817625236748
# ----- Đang dự đoán cho dòng thứ 800 là 7.246318246071664
# ----- Đang dự đoán cho dòng thứ 801 là 6.398381825745011
# ----- Đang dự đoán cho dòng thứ 802 là nan
# ----- Đang dự đoán cho dòng thứ 803 là 7.127629696220372
# ----- Đang dự đoán cho dòng thứ 804 là 6.969562231327638
# ----- Đang dự đoán cho dòng thứ 805 là 8.5
# ----- Đang dự đoán cho dòng thứ 806 là 5.3
# ----- Đang dự đoán cho dòng thứ 807 là 6.866666666666667
# ----- Đang dự đoán cho dòng thứ 808 là 6.335246858715885
# ----- Đang dự đoán cho dòng thứ 809 là 9.7
# ----- Đang dự đoán cho dòng thứ 810 là 7.998253574834435
# ----- Đang dự đoán cho dòng thứ 811 là 8.829751051785054
# ----- Đang dự đoán cho dòng thứ 812 là 5.702108311899541
# ----- Đang dự đoán cho dòng thứ 813 là nan
# ----- Đang dự đoán cho dòng thứ 814 là 8.75
# ----- Đang dự đoán cho dòng thứ 815 là nan
# ----- Đang dự đoán cho dòng thứ 816 là 8.046693697050687
# ----- Đang dự đoán cho dòng thứ 817 là 7.662410558909265
# ----- Đang dự đoán cho dòng thứ 818 là 7.705338277334582
# ----- Đang dự đoán cho dòng thứ 819 là 5.999999999999999
# ----- Đang dự đoán cho dòng thứ 820 là nan
# ----- Đang dự đoán cho dòng thứ 821 là 0
# ----- Đang dự đoán cho dòng thứ 822 là 0
# ----- Đang dự đoán cho dòng thứ 823 là 7.0
# ----- Đang dự đoán cho dòng thứ 824 là 10.0
# ----- Đang dự đoán cho dòng thứ 825 là 8.4
# ----- Đang dự đoán cho dòng thứ 826 là 8.576348526845587
# ----- Đang dự đoán cho dòng thứ 827 là 0
# ----- Đang dự đoán cho dòng thứ 828 là 7.008003451601625
# ----- Đang dự đoán cho dòng thứ 829 là nan
# ----- Đang dự đoán cho dòng thứ 830 là 4.0
# ----- Đang dự đoán cho dòng thứ 831 là 8.51677810292994
# ----- Đang dự đoán cho dòng thứ 832 là 6.4
# ----- Đang dự đoán cho dòng thứ 833 là nan
# ----- Đang dự đoán cho dòng thứ 834 là 0
# ----- Đang dự đoán cho dòng thứ 835 là 0
# ----- Đang dự đoán cho dòng thứ 836 là 0
# ----- Đang dự đoán cho dòng thứ 837 là 7.911512392165161
# ----- Đang dự đoán cho dòng thứ 838 là 7.35048320191264
# ----- Đang dự đoán cho dòng thứ 839 là 10.0
# ----- Đang dự đoán cho dòng thứ 840 là 9.492039913476665
# ----- Đang dự đoán cho dòng thứ 841 là nan
# ----- Đang dự đoán cho dòng thứ 842 là 8.90091190915277
# ----- Đang dự đoán cho dòng thứ 843 là 5.5145198591387565
# ----- Đang dự đoán cho dòng thứ 844 là 8.714056575636459
# ----- Đang dự đoán cho dòng thứ 845 là 6.655002989222542
# ----- Đang dự đoán cho dòng thứ 846 là 6.7892011219187935
# ----- Đang dự đoán cho dòng thứ 847 là 6.7772328934765715
# ----- Đang dự đoán cho dòng thứ 848 là 7.906746633146723
# ----- Đang dự đoán cho dòng thứ 849 là 6.639259909447109
# ----- Đang dự đoán cho dòng thứ 850 là 9.749475130276355
# ----- Đang dự đoán cho dòng thứ 851 là 0
# ----- Đang dự đoán cho dòng thứ 852 là 0
# ----- Đang dự đoán cho dòng thứ 853 là 8.524642762488961
# ----- Đang dự đoán cho dòng thứ 854 là 7.769272789115449
# ----- Đang dự đoán cho dòng thứ 855 là 9.4
# ----- Đang dự đoán cho dòng thứ 856 là 6.0
# ----- Đang dự đoán cho dòng thứ 857 là 8.666666666666666
# ----- Đang dự đoán cho dòng thứ 858 là 6.146282213797078
# ----- Đang dự đoán cho dòng thứ 859 là 4.939592311058547
# ----- Đang dự đoán cho dòng thứ 860 là 9.047738428839041
# ----- Đang dự đoán cho dòng thứ 861 là 6.1
# ----- Đang dự đoán cho dòng thứ 862 là 6.4791401766559025
# ----- Đang dự đoán cho dòng thứ 863 là 8.5
# ----- Đang dự đoán cho dòng thứ 864 là nan
# ----- Đang dự đoán cho dòng thứ 865 là 6.0
# ----- Đang dự đoán cho dòng thứ 866 là 8.11398000840016
# ----- Đang dự đoán cho dòng thứ 867 là 8.35
# ----- Đang dự đoán cho dòng thứ 868 là 7.440512335690118
# ----- Đang dự đoán cho dòng thứ 869 là 7.0
# ----- Đang dự đoán cho dòng thứ 870 là 7.358683650302642
# ----- Đang dự đoán cho dòng thứ 871 là 7.0
# ----- Đang dự đoán cho dòng thứ 872 là nan
# ----- Đang dự đoán cho dòng thứ 873 là 9.377676675894604
# ----- Đang dự đoán cho dòng thứ 874 là 8.7
# ----- Đang dự đoán cho dòng thứ 875 là 9.878852276161252
# ----- Đang dự đoán cho dòng thứ 876 là 7.354847076692346
# ----- Đang dự đoán cho dòng thứ 877 là 7.709638461908769
# ----- Đang dự đoán cho dòng thứ 878 là 6.844693165842916
# ----- Đang dự đoán cho dòng thứ 879 là 6.895272058908212
# ----- Đang dự đoán cho dòng thứ 880 là 8.0
# ----- Đang dự đoán cho dòng thứ 881 là 8.0
# ----- Đang dự đoán cho dòng thứ 882 là 7.499999999999999
# ----- Đang dự đoán cho dòng thứ 883 là 0
# ----- Đang dự đoán cho dòng thứ 884 là 8.615179353797435
# ----- Đang dự đoán cho dòng thứ 885 là nan
# ----- Đang dự đoán cho dòng thứ 886 là 10.0
# ----- Đang dự đoán cho dòng thứ 887 là 5.9114604317267405
# ----- Đang dự đoán cho dòng thứ 888 là 8.381932361224031
# ----- Đang dự đoán cho dòng thứ 889 là nan
# ----- Đang dự đoán cho dòng thứ 890 là nan
# ----- Đang dự đoán cho dòng thứ 891 là 5.8
# ----- Đang dự đoán cho dòng thứ 892 là 6.844693165842916
# ----- Đang dự đoán cho dòng thứ 893 là 6.5781844435876655
# ----- Đang dự đoán cho dòng thứ 894 là 8.448865277135393
# ----- Đang dự đoán cho dòng thứ 895 là nan
# ----- Đang dự đoán cho dòng thứ 896 là 8.430817689468673
# ----- Đang dự đoán cho dòng thứ 897 là 9.757506926160069
# ----- Đang dự đoán cho dòng thứ 898 là 9.000301065450811
# ----- Đang dự đoán cho dòng thứ 899 là 6.548084486829328
# ----- Đang dự đoán cho dòng thứ 900 là 8.714768579438251
# ----- Đang dự đoán cho dòng thứ 901 là 5.1
# ----- Đang dự đoán cho dòng thứ 902 là 0
# ----- Đang dự đoán cho dòng thứ 903 là 5.670555078437728
# ----- Đang dự đoán cho dòng thứ 904 là 9.4
# ----- Đang dự đoán cho dòng thứ 905 là 8.256688647791986
# ----- Đang dự đoán cho dòng thứ 906 là 0
# ----- Đang dự đoán cho dòng thứ 907 là 9.514351156214412
# ----- Đang dự đoán cho dòng thứ 908 là 6.4539239819063745
# ----- Đang dự đoán cho dòng thứ 909 là 6.1000000000000005
# ----- Đang dự đoán cho dòng thứ 910 là 6.051643416523288
# ----- Đang dự đoán cho dòng thứ 911 là 1.0
# ----- Đang dự đoán cho dòng thứ 912 là 8.656945651877185
# ----- Đang dự đoán cho dòng thứ 913 là 6.670252627844575
# ----- Đang dự đoán cho dòng thứ 914 là 8.054303350971232
# ----- Đang dự đoán cho dòng thứ 915 là 7.962555883259644
# ----- Đang dự đoán cho dòng thứ 916 là 5.5
# ----- Đang dự đoán cho dòng thứ 917 là 8.879150186638077
# ----- Đang dự đoán cho dòng thứ 918 là 7.56343264701909
# ----- Đang dự đoán cho dòng thứ 919 là 9.1
# ----- Đang dự đoán cho dòng thứ 920 là 9.10072297114203
# ----- Đang dự đoán cho dòng thứ 921 là 8.479234105675323
# ----- Đang dự đoán cho dòng thứ 922 là 8.493302448638445
# ----- Đang dự đoán cho dòng thứ 923 là 8.334024865135822
# ----- Đang dự đoán cho dòng thứ 924 là 0
# ----- Đang dự đoán cho dòng thứ 925 là 5.8
# ----- Đang dự đoán cho dòng thứ 926 là 1.0
# ----- Đang dự đoán cho dòng thứ 927 là 6.5
# ----- Đang dự đoán cho dòng thứ 928 là 9.666666666666668
# ----- Đang dự đoán cho dòng thứ 929 là 6.473481232294747
# ----- Đang dự đoán cho dòng thứ 930 là nan
# ----- Đang dự đoán cho dòng thứ 931 là 6.0
# ----- Đang dự đoán cho dòng thứ 932 là 6.201108477505951
# ----- Đang dự đoán cho dòng thứ 933 là 9.0
# ----- Đang dự đoán cho dòng thứ 934 là 0
# ----- Đang dự đoán cho dòng thứ 935 là 8.2
# ----- Đang dự đoán cho dòng thứ 936 là 6.382977506200067
# ----- Đang dự đoán cho dòng thứ 937 là 8.011783601590546
# ----- Đang dự đoán cho dòng thứ 938 là 9.7
# ----- Đang dự đoán cho dòng thứ 939 là 8.4
# ----- Đang dự đoán cho dòng thứ 940 là 8.470845809324327
# ----- Đang dự đoán cho dòng thứ 941 là 7.31130198567709
# ----- Đang dự đoán cho dòng thứ 942 là 5.783194505538828
# ----- Đang dự đoán cho dòng thứ 943 là 4.77717043069602
# ----- Đang dự đoán cho dòng thứ 944 là 0
# ----- Đang dự đoán cho dòng thứ 945 là 8.523244079349672
# ----- Đang dự đoán cho dòng thứ 946 là nan
# ----- Đang dự đoán cho dòng thứ 947 là 7.343561903854205
# ----- Đang dự đoán cho dòng thứ 948 là 8.066086864901216
# ----- Đang dự đoán cho dòng thứ 949 là nan
# ----- Đang dự đoán cho dòng thứ 950 là 3.0
# ----- Đang dự đoán cho dòng thứ 951 là 7.337037054469963
# ----- Đang dự đoán cho dòng thứ 952 là nan
# ----- Đang dự đoán cho dòng thứ 953 là 5.25
# ----- Đang dự đoán cho dòng thứ 954 là 8.125246796541502
# ----- Đang dự đoán cho dòng thứ 955 là 8.799790493884016
# ----- Đang dự đoán cho dòng thứ 956 là 9.0
# ----- Đang dự đoán cho dòng thứ 957 là nan
# ----- Đang dự đoán cho dòng thứ 958 là 0
# Tổng thời gian dự đoán: 39.56469759146373 minutes

# %%
# hàm dữ đoán trên tập test
def get_recommendation_on_test_item_2(test):
  X_test_pred = []
  X_test_userid = test['userId'].tolist()   #lấy ra danh sách các userID trong tập test
  X_test_movieID = test['movieId'].tolist()

  print("------Dự đoán cho tập test với {} điểm dữ liệu------".format(len(X_test_movieID)))

  for i in range(len(X_test_movieID)):        #lấy ra từng user
    list_R = get_recommendation_based_on_item(X_test_movieID[i], 100, 'cosine', 10)    # lấy ra danh sách khuyến nghị dựa trên USER

    check = 0
    for j in list_R:
      if(X_test_userid[i] == j[0]):     #j[1] là lấy movieID predict
        X_test_pred.append(j[1])
        check = 1
    if(check == 0):
      X_test_pred.append(0)
    print('----- Đang dự đoán cho dòng thứ {}'.format(i), 'là {}'.format(X_test_pred[i]))
  return X_test_pred

# %%
start = time.time()
X_test_pred_item_cosine = get_recommendation_on_test_item_2(X_test)
end = time.time()
print(f'Tổng thời gian dự đoán: {(end - start)/60} minutes')
# Out:
# ------Dự đoán cho tập test với 959 điểm dữ liệu------
# ----- Đang dự đoán cho dòng thứ 0 là 8.338461538461539
# ----- Đang dự đoán cho dòng thứ 1 là 0
# ----- Đang dự đoán cho dòng thứ 2 là 7.875
# ----- Đang dự đoán cho dòng thứ 3 là 8.014583333333334
# ----- Đang dự đoán cho dòng thứ 4 là 8.500943574561786
# ----- Đang dự đoán cho dòng thứ 5 là 7.5
# ----- Đang dự đoán cho dòng thứ 6 là 8.6
# <ipython-input-31-245d4e089628>:99: RuntimeWarning: invalid value encountered in double_scalars
#   list_ranking = [(userid, tot/sum_similarity[userid]) for userid, tot in total.items()]
# ----- Đang dự đoán cho dòng thứ 7 là 6.706985690586417
# ----- Đang dự đoán cho dòng thứ 8 là 8.049999999999999
# ----- Đang dự đoán cho dòng thứ 9 là 7.099522185236129
# ----- Đang dự đoán cho dòng thứ 10 là 6.15
# ----- Đang dự đoán cho dòng thứ 11 là 8.0
# ----- Đang dự đoán cho dòng thứ 12 là 6.8
# ----- Đang dự đoán cho dòng thứ 13 là 9.4
# ----- Đang dự đoán cho dòng thứ 14 là 8.5
# ----- Đang dự đoán cho dòng thứ 15 là 7.763250493090887
# ----- Đang dự đoán cho dòng thứ 16 là 6.0
# ----- Đang dự đoán cho dòng thứ 17 là 8.315094339622641
# ----- Đang dự đoán cho dòng thứ 18 là 7.466666666666666
# ----- Đang dự đoán cho dòng thứ 19 là 8.0
# ----- Đang dự đoán cho dòng thứ 20 là 7.170161962151357
# ----- Đang dự đoán cho dòng thứ 21 là 0
# ----- Đang dự đoán cho dòng thứ 22 là 6.956525581083903
# ----- Đang dự đoán cho dòng thứ 23 là 10.0
# ----- Đang dự đoán cho dòng thứ 24 là 7.12273345687932
# ----- Đang dự đoán cho dòng thứ 25 là 0
# ----- Đang dự đoán cho dòng thứ 26 là 7.733333333333333
# ----- Đang dự đoán cho dòng thứ 27 là 7.6704314652690835
# ----- Đang dự đoán cho dòng thứ 28 là 7.676037546090175
# ----- Đang dự đoán cho dòng thứ 29 là 8.7
# ----- Đang dự đoán cho dòng thứ 30 là 0
# ----- Đang dự đoán cho dòng thứ 31 là 0
# ----- Đang dự đoán cho dòng thứ 32 là 7.174215571608684
# ----- Đang dự đoán cho dòng thứ 33 là 5.966666666666666
# ----- Đang dự đoán cho dòng thứ 34 là 8.243466081254153
# ----- Đang dự đoán cho dòng thứ 35 là 7.188888888888887
# ----- Đang dự đoán cho dòng thứ 36 là 7.8999999999999995
# ----- Đang dự đoán cho dòng thứ 37 là 6.0
# ----- Đang dự đoán cho dòng thứ 38 là 8.0
# ----- Đang dự đoán cho dòng thứ 39 là 9.0
# ----- Đang dự đoán cho dòng thứ 40 là 9.0
# ----- Đang dự đoán cho dòng thứ 41 là 6.4
# ----- Đang dự đoán cho dòng thứ 42 là 9.7
# ----- Đang dự đoán cho dòng thứ 43 là 8.26
# ----- Đang dự đoán cho dòng thứ 44 là 10.0
# ----- Đang dự đoán cho dòng thứ 45 là 7.18108108108108
# ----- Đang dự đoán cho dòng thứ 46 là 8.542857142857143
# ----- Đang dự đoán cho dòng thứ 47 là 0
# ----- Đang dự đoán cho dòng thứ 48 là 8.0
# ----- Đang dự đoán cho dòng thứ 49 là 9.7
# ----- Đang dự đoán cho dòng thứ 50 là 0
# ----- Đang dự đoán cho dòng thứ 51 là 10.0
# ----- Đang dự đoán cho dòng thứ 52 là 7.5178762601705085
# ----- Đang dự đoán cho dòng thứ 53 là 7.2
# ----- Đang dự đoán cho dòng thứ 54 là 6.3
# ----- Đang dự đoán cho dòng thứ 55 là 8.85
# ----- Đang dự đoán cho dòng thứ 56 là 8.0
# ----- Đang dự đoán cho dòng thứ 57 là 8.623710132940772
# ----- Đang dự đoán cho dòng thứ 58 là 9.058888308239462
# ----- Đang dự đoán cho dòng thứ 59 là 0
# ----- Đang dự đoán cho dòng thứ 60 là 7.0
# ----- Đang dự đoán cho dòng thứ 61 là 5.749135204471364
# ----- Đang dự đoán cho dòng thứ 62 là 0
# ----- Đang dự đoán cho dòng thứ 63 là 0
# ----- Đang dự đoán cho dòng thứ 64 là 9.561104538413076
# ----- Đang dự đoán cho dòng thứ 65 là 7.333683879892566
# ----- Đang dự đoán cho dòng thứ 66 là 7.4156249999999995
# ----- Đang dự đoán cho dòng thứ 67 là 0
# ----- Đang dự đoán cho dòng thứ 68 là 7.404545454545455
# ----- Đang dự đoán cho dòng thứ 69 là 0
# ----- Đang dự đoán cho dòng thứ 70 là 7.624444444444445
# ----- Đang dự đoán cho dòng thứ 71 là 7.714223388922323
# ----- Đang dự đoán cho dòng thứ 72 là 8.019251172633256
# ----- Đang dự đoán cho dòng thứ 73 là 7.083333333333333
# ----- Đang dự đoán cho dòng thứ 74 là 8.8
# ----- Đang dự đoán cho dòng thứ 75 là 0
# ----- Đang dự đoán cho dòng thứ 76 là 8.5
# ----- Đang dự đoán cho dòng thứ 77 là 0
# ----- Đang dự đoán cho dòng thứ 78 là 7.166666666666667
# ----- Đang dự đoán cho dòng thứ 79 là 9.0
# ----- Đang dự đoán cho dòng thứ 80 là 7.523376623376623
# ----- Đang dự đoán cho dòng thứ 81 là 5.0
# ----- Đang dự đoán cho dòng thứ 82 là 7.75
# ----- Đang dự đoán cho dòng thứ 83 là 9.6
# ----- Đang dự đoán cho dòng thứ 84 là 6.304832713754647
# ----- Đang dự đoán cho dòng thứ 85 là 7.17962588603192
# ----- Đang dự đoán cho dòng thứ 86 là 8.3375
# ----- Đang dự đoán cho dòng thứ 87 là 7.1000000000000005
# ----- Đang dự đoán cho dòng thứ 88 là 7.281818181818181
# ----- Đang dự đoán cho dòng thứ 89 là 0
# ----- Đang dự đoán cho dòng thứ 90 là 7.637750249946812
# ----- Đang dự đoán cho dòng thứ 91 là 7.854208568893458
# ----- Đang dự đoán cho dòng thứ 92 là 7.5
# ----- Đang dự đoán cho dòng thứ 93 là 6.2
# ----- Đang dự đoán cho dòng thứ 94 là 7.62004095249602
# ----- Đang dự đoán cho dòng thứ 95 là 8.5
# ----- Đang dự đoán cho dòng thứ 96 là 7.887500000000001
# ----- Đang dự đoán cho dòng thứ 97 là 8.020043520753081
# ----- Đang dự đoán cho dòng thứ 98 là 7.750000000000001
# ----- Đang dự đoán cho dòng thứ 99 là 6.6
# ----- Đang dự đoán cho dòng thứ 100 là 7.120008156751998
# ----- Đang dự đoán cho dòng thứ 101 là 0
# ----- Đang dự đoán cho dòng thứ 102 là 6.0
# ----- Đang dự đoán cho dòng thứ 103 là 6.955555555555556
# ----- Đang dự đoán cho dòng thứ 104 là 10.0
# ----- Đang dự đoán cho dòng thứ 105 là 8.0
# ----- Đang dự đoán cho dòng thứ 106 là 6.95
# ----- Đang dự đoán cho dòng thứ 107 là 8.0
# ----- Đang dự đoán cho dòng thứ 108 là 8.5
# ----- Đang dự đoán cho dòng thứ 109 là 0
# ----- Đang dự đoán cho dòng thứ 110 là 8.375
# ----- Đang dự đoán cho dòng thứ 111 là 7.3
# ----- Đang dự đoán cho dòng thứ 112 là 0
# ----- Đang dự đoán cho dòng thứ 113 là 5.775
# ----- Đang dự đoán cho dòng thứ 114 là 7.7
# ----- Đang dự đoán cho dòng thứ 115 là 7.677421088839563
# ----- Đang dự đoán cho dòng thứ 116 là 9.75
# ----- Đang dự đoán cho dòng thứ 117 là 7.564912280701755
# ----- Đang dự đoán cho dòng thứ 118 là 7.888888888888889
# ----- Đang dự đoán cho dòng thứ 119 là 7.428208734082074
# ----- Đang dự đoán cho dòng thứ 120 là 8.105555555555556
# ----- Đang dự đoán cho dòng thứ 121 là 7.366666666666667
# ----- Đang dự đoán cho dòng thứ 122 là 8.266666666666667
# ----- Đang dự đoán cho dòng thứ 123 là 6.734246005195635
# ----- Đang dự đoán cho dòng thứ 124 là 7.4960278916807574
# ----- Đang dự đoán cho dòng thứ 125 là 7.627260758254572
# ----- Đang dự đoán cho dòng thứ 126 là 8.16
# ----- Đang dự đoán cho dòng thứ 127 là 6.666666666666667
# ----- Đang dự đoán cho dòng thứ 128 là 8.0
# ----- Đang dự đoán cho dòng thứ 129 là 6.990742295007078
# ----- Đang dự đoán cho dòng thứ 130 là 9.0
# ----- Đang dự đoán cho dòng thứ 131 là 10.0
# ----- Đang dự đoán cho dòng thứ 132 là 6.0
# ----- Đang dự đoán cho dòng thứ 133 là 8.55
# ----- Đang dự đoán cho dòng thứ 134 là 9.05
# ----- Đang dự đoán cho dòng thứ 135 là 7.047999293128565
# ----- Đang dự đoán cho dòng thứ 136 là 6.67504540972452
# ----- Đang dự đoán cho dòng thứ 137 là 7.925
# ----- Đang dự đoán cho dòng thứ 138 là 7.381818181818182
# ----- Đang dự đoán cho dòng thứ 139 là 8.032353727814337
# ----- Đang dự đoán cho dòng thứ 140 là 8.233333333333333
# ----- Đang dự đoán cho dòng thứ 141 là 8.7
# ----- Đang dự đoán cho dòng thứ 142 là 7.75
# ----- Đang dự đoán cho dòng thứ 143 là 7.293363097494936
# ----- Đang dự đoán cho dòng thứ 144 là 7.5
# ----- Đang dự đoán cho dòng thứ 145 là 8.11111111111111
# ----- Đang dự đoán cho dòng thứ 146 là 7.516026764782139
# ----- Đang dự đoán cho dòng thứ 147 là 6.822444589654807
# ----- Đang dự đoán cho dòng thứ 148 là 8.0
# ----- Đang dự đoán cho dòng thứ 149 là 7.0
# ----- Đang dự đoán cho dòng thứ 150 là 7.987590474927253
# ----- Đang dự đoán cho dòng thứ 151 là 7.933333333333334
# ----- Đang dự đoán cho dòng thứ 152 là 7.368303429746021
# ----- Đang dự đoán cho dòng thứ 153 là 8.859928094759235
# ----- Đang dự đoán cho dòng thứ 154 là 9.0
# ----- Đang dự đoán cho dòng thứ 155 là 8.166666666666666
# ----- Đang dự đoán cho dòng thứ 156 là 6.583333333333333
# ----- Đang dự đoán cho dòng thứ 157 là 7.25
# ----- Đang dự đoán cho dòng thứ 158 là 8.28426507345164
# ----- Đang dự đoán cho dòng thứ 159 là 6.3999999999999995
# ----- Đang dự đoán cho dòng thứ 160 là 7.638379941732778
# ----- Đang dự đoán cho dòng thứ 161 là 5.5
# ----- Đang dự đoán cho dòng thứ 162 là 7.219365356980854
# ----- Đang dự đoán cho dòng thứ 163 là 9.0
# ----- Đang dự đoán cho dòng thứ 164 là 7.419999999999999
# ----- Đang dự đoán cho dòng thứ 165 là 9.35
# ----- Đang dự đoán cho dòng thứ 166 là 7.6
# ----- Đang dự đoán cho dòng thứ 167 là 0
# ----- Đang dự đoán cho dòng thứ 168 là 7.2084373799571315
# ----- Đang dự đoán cho dòng thứ 169 là 8.3125
# ----- Đang dự đoán cho dòng thứ 170 là 6.85
# ----- Đang dự đoán cho dòng thứ 171 là 9.323173153367605
# ----- Đang dự đoán cho dòng thứ 172 là 10.0
# ----- Đang dự đoán cho dòng thứ 173 là 8.166666666666666
# ----- Đang dự đoán cho dòng thứ 174 là 10.0
# ----- Đang dự đoán cho dòng thứ 175 là 5.566666666666666
# ----- Đang dự đoán cho dòng thứ 176 là 6.5
# ----- Đang dự đoán cho dòng thứ 177 là 7.5
# ----- Đang dự đoán cho dòng thứ 178 là 6.840266418001505
# ----- Đang dự đoán cho dòng thứ 179 là 0
# ----- Đang dự đoán cho dòng thứ 180 là 0
# ----- Đang dự đoán cho dòng thứ 181 là 8.5
# ----- Đang dự đoán cho dòng thứ 182 là 7.783333333333334
# ----- Đang dự đoán cho dòng thứ 183 là 0
# ----- Đang dự đoán cho dòng thứ 184 là 8.0
# ----- Đang dự đoán cho dòng thứ 185 là 8.98
# ----- Đang dự đoán cho dòng thứ 186 là 8.316666666666666
# ----- Đang dự đoán cho dòng thứ 187 là 9.11111111111111
# ----- Đang dự đoán cho dòng thứ 188 là 8.82012502771569
# ----- Đang dự đoán cho dòng thứ 189 là 8.533333333333333
# ----- Đang dự đoán cho dòng thứ 190 là 7.902704764075999
# ----- Đang dự đoán cho dòng thứ 191 là 8.0
# ----- Đang dự đoán cho dòng thứ 192 là 6.5
# ----- Đang dự đoán cho dòng thứ 193 là 8.512598285810478
# ----- Đang dự đoán cho dòng thứ 194 là 9.1
# ----- Đang dự đoán cho dòng thứ 195 là 7.699420126347171
# ----- Đang dự đoán cho dòng thứ 196 là 0
# ----- Đang dự đoán cho dòng thứ 197 là 7.5
# ----- Đang dự đoán cho dòng thứ 198 là 8.5
# ----- Đang dự đoán cho dòng thứ 199 là 7.723275862068966
# ----- Đang dự đoán cho dòng thứ 200 là 9.1
# ----- Đang dự đoán cho dòng thứ 201 là 7.25
# ----- Đang dự đoán cho dòng thứ 202 là 6.7
# ----- Đang dự đoán cho dòng thứ 203 là 7.84074074074074
# ----- Đang dự đoán cho dòng thứ 204 là 7.6
# ----- Đang dự đoán cho dòng thứ 205 là 5.628571428571429
# ----- Đang dự đoán cho dòng thứ 206 là 8.7
# ----- Đang dự đoán cho dòng thứ 207 là 9.25
# ----- Đang dự đoán cho dòng thứ 208 là 9.7
# ----- Đang dự đoán cho dòng thứ 209 là 7.926666666666667
# ----- Đang dự đoán cho dòng thứ 210 là 6.988888888888889
# ----- Đang dự đoán cho dòng thứ 211 là 7.8538461538461535
# ----- Đang dự đoán cho dòng thứ 212 là 0
# ----- Đang dự đoán cho dòng thứ 213 là 0
# ----- Đang dự đoán cho dòng thứ 214 là 7.0
# ----- Đang dự đoán cho dòng thứ 215 là 6.8
# ----- Đang dự đoán cho dòng thứ 216 là 6.34
# ----- Đang dự đoán cho dòng thứ 217 là 7.966666666666666
# ----- Đang dự đoán cho dòng thứ 218 là 6.944444444444445
# ----- Đang dự đoán cho dòng thứ 219 là 7.05
# ----- Đang dự đoán cho dòng thứ 220 là 9.0
# ----- Đang dự đoán cho dòng thứ 221 là 7.4
# ----- Đang dự đoán cho dòng thứ 222 là 7.6658536585365855
# ----- Đang dự đoán cho dòng thứ 223 là 8.0
# ----- Đang dự đoán cho dòng thứ 224 là 7.978004789244981
# ----- Đang dự đoán cho dòng thứ 225 là 7.1899999999999995
# ----- Đang dự đoán cho dòng thứ 226 là 8.5
# ----- Đang dự đoán cho dòng thứ 227 là 10.0
# ----- Đang dự đoán cho dòng thứ 228 là 7.763369000517533
# ----- Đang dự đoán cho dòng thứ 229 là 0
# ----- Đang dự đoán cho dòng thứ 230 là 7.665789473684211
# ----- Đang dự đoán cho dòng thứ 231 là 0
# ----- Đang dự đoán cho dòng thứ 232 là 8.392307692307693
# ----- Đang dự đoán cho dòng thứ 233 là 7.637132919457896
# ----- Đang dự đoán cho dòng thứ 234 là 7.294444444444445
# ----- Đang dự đoán cho dòng thứ 235 là 0
# ----- Đang dự đoán cho dòng thứ 236 là 0
# ----- Đang dự đoán cho dòng thứ 237 là 8.5
# ----- Đang dự đoán cho dòng thứ 238 là 7.333333333333333
# ----- Đang dự đoán cho dòng thứ 239 là 0
# ----- Đang dự đoán cho dòng thứ 240 là 7.6505196440683765
# ----- Đang dự đoán cho dòng thứ 241 là 6.85
# ----- Đang dự đoán cho dòng thứ 242 là 7.447395052134557
# ----- Đang dự đoán cho dòng thứ 243 là 7.717947996817951
# ----- Đang dự đoán cho dòng thứ 244 là 7.747999999999999
# ----- Đang dự đoán cho dòng thứ 245 là 6.282628562389686
# ----- Đang dự đoán cho dòng thứ 246 là 0
# ----- Đang dự đoán cho dòng thứ 247 là 8.031666666666666
# ----- Đang dự đoán cho dòng thứ 248 là 7.239999999999999
# ----- Đang dự đoán cho dòng thứ 249 là 5.85
# ----- Đang dự đoán cho dòng thứ 250 là 7.448156299631384
# ----- Đang dự đoán cho dòng thứ 251 là 8.032964393259451
# ----- Đang dự đoán cho dòng thứ 252 là 7.0894736842105255
# ----- Đang dự đoán cho dòng thứ 253 là 6.40469025486721
# ----- Đang dự đoán cho dòng thứ 254 là 9.019351918726375
# ----- Đang dự đoán cho dòng thứ 255 là 8.716666666666667
# ----- Đang dự đoán cho dòng thứ 256 là 6.833333333333333
# ----- Đang dự đoán cho dòng thứ 257 là 8.068181818181818
# ----- Đang dự đoán cho dòng thứ 258 là 6.875
# ----- Đang dự đoán cho dòng thứ 259 là 8.04
# ----- Đang dự đoán cho dòng thứ 260 là 3.0
# ----- Đang dự đoán cho dòng thứ 261 là 0
# ----- Đang dự đoán cho dòng thứ 262 là 8.416666666666666
# ----- Đang dự đoán cho dòng thứ 263 là 6.8999999999999995
# ----- Đang dự đoán cho dòng thứ 264 là 8.235294117647058
# ----- Đang dự đoán cho dòng thứ 265 là 7.6499999999999995
# ----- Đang dự đoán cho dòng thứ 266 là 6.433333333333334
# ----- Đang dự đoán cho dòng thứ 267 là 6.533505643225899
# ----- Đang dự đoán cho dòng thứ 268 là 8.3
# ----- Đang dự đoán cho dòng thứ 269 là 7.7
# ----- Đang dự đoán cho dòng thứ 270 là 6.0
# ----- Đang dự đoán cho dòng thứ 271 là 6.6
# ----- Đang dự đoán cho dòng thứ 272 là 8.066666666666668
# ----- Đang dự đoán cho dòng thứ 273 là 7.800735101393192
# ----- Đang dự đoán cho dòng thứ 274 là 0
# ----- Đang dự đoán cho dòng thứ 275 là 0
# ----- Đang dự đoán cho dòng thứ 276 là 6.65
# ----- Đang dự đoán cho dòng thứ 277 là 6.5200000000000005
# ----- Đang dự đoán cho dòng thứ 278 là 7.75
# ----- Đang dự đoán cho dòng thứ 279 là 0
# ----- Đang dự đoán cho dòng thứ 280 là 7.76
# ----- Đang dự đoán cho dòng thứ 281 là 8.2
# ----- Đang dự đoán cho dòng thứ 282 là 8.029545454545454
# ----- Đang dự đoán cho dòng thứ 283 là 0
# ----- Đang dự đoán cho dòng thứ 284 là 6.4
# ----- Đang dự đoán cho dòng thứ 285 là 7.0
# ----- Đang dự đoán cho dòng thứ 286 là 7.0
# ----- Đang dự đoán cho dòng thứ 287 là 6.4
# ----- Đang dự đoán cho dòng thứ 288 là 7.498906444596857
# ----- Đang dự đoán cho dòng thứ 289 là 0
# ----- Đang dự đoán cho dòng thứ 290 là 7.573665987237392
# ----- Đang dự đoán cho dòng thứ 291 là 7.3090909090909095
# ----- Đang dự đoán cho dòng thứ 292 là 7.0
# ----- Đang dự đoán cho dòng thứ 293 là 7.5200000000000005
# ----- Đang dự đoán cho dòng thứ 294 là 8.66
# ----- Đang dự đoán cho dòng thứ 295 là 0
# ----- Đang dự đoán cho dòng thứ 296 là 7.48695652173913
# ----- Đang dự đoán cho dòng thứ 297 là 8.051441303196105
# ----- Đang dự đoán cho dòng thứ 298 là 7.000686724571327
# ----- Đang dự đoán cho dòng thứ 299 là 7.340000000000001
# ----- Đang dự đoán cho dòng thứ 300 là 9.4
# ----- Đang dự đoán cho dòng thứ 301 là 6.3
# ----- Đang dự đoán cho dòng thứ 302 là 5.0
# ----- Đang dự đoán cho dòng thứ 303 là 0
# ----- Đang dự đoán cho dòng thứ 304 là 0
# ----- Đang dự đoán cho dòng thứ 305 là 7.236231370650169
# ----- Đang dự đoán cho dòng thứ 306 là 10.0
# ----- Đang dự đoán cho dòng thứ 307 là 0
# ----- Đang dự đoán cho dòng thứ 308 là 6.0
# ----- Đang dự đoán cho dòng thứ 309 là 7.2
# ----- Đang dự đoán cho dòng thứ 310 là 7.7519480519480535
# ----- Đang dự đoán cho dòng thứ 311 là 10.0
# ----- Đang dự đoán cho dòng thứ 312 là 7.0
# ----- Đang dự đoán cho dòng thứ 313 là 9.0
# ----- Đang dự đoán cho dòng thứ 314 là 8.031404188940117
# ----- Đang dự đoán cho dòng thứ 315 là 6.666666666666667
# ----- Đang dự đoán cho dòng thứ 316 là 0
# ----- Đang dự đoán cho dòng thứ 317 là 6.8
# ----- Đang dự đoán cho dòng thứ 318 là 7.233333333333334
# ----- Đang dự đoán cho dòng thứ 319 là 7.0
# ----- Đang dự đoán cho dòng thứ 320 là 8.7
# ----- Đang dự đoán cho dòng thứ 321 là 6.6
# ----- Đang dự đoán cho dòng thứ 322 là 10.0
# ----- Đang dự đoán cho dòng thứ 323 là 10.0
# ----- Đang dự đoán cho dòng thứ 324 là 7.448451119641518
# ----- Đang dự đoán cho dòng thứ 325 là 8.319613872137186
# ----- Đang dự đoán cho dòng thứ 326 là 7.705504455834751
# ----- Đang dự đoán cho dòng thứ 327 là 6.883333333333334
# ----- Đang dự đoán cho dòng thứ 328 là 7.735714285714287
# ----- Đang dự đoán cho dòng thứ 329 là 4.9
# ----- Đang dự đoán cho dòng thứ 330 là 7.5
# ----- Đang dự đoán cho dòng thứ 331 là 8.5
# ----- Đang dự đoán cho dòng thứ 332 là 8.547165868509332
# ----- Đang dự đoán cho dòng thứ 333 là 7.275
# ----- Đang dự đoán cho dòng thứ 334 là 7.164
# ----- Đang dự đoán cho dòng thứ 335 là 8.024999999999999
# ----- Đang dự đoán cho dòng thứ 336 là 8.0
# ----- Đang dự đoán cho dòng thứ 337 là 7.666666666666667
# ----- Đang dự đoán cho dòng thứ 338 là 6.0
# ----- Đang dự đoán cho dòng thứ 339 là 10.0
# ----- Đang dự đoán cho dòng thứ 340 là 8.14760407997942
# ----- Đang dự đoán cho dòng thứ 341 là 9.849544951561773
# ----- Đang dự đoán cho dòng thứ 342 là 5.875
# ----- Đang dự đoán cho dòng thứ 343 là 8.171428571428573
# ----- Đang dự đoán cho dòng thứ 344 là 4.5
# ----- Đang dự đoán cho dòng thứ 345 là 8.330769230769231
# ----- Đang dự đoán cho dòng thứ 346 là 5.0
# ----- Đang dự đoán cho dòng thứ 347 là 0
# ----- Đang dự đoán cho dòng thứ 348 là 7.751851851851852
# ----- Đang dự đoán cho dòng thứ 349 là 7.740135127051354
# ----- Đang dự đoán cho dòng thứ 350 là 7.550000000000001
# ----- Đang dự đoán cho dòng thứ 351 là 8.423076923076923
# ----- Đang dự đoán cho dòng thứ 352 là 7.452173913043478
# ----- Đang dự đoán cho dòng thứ 353 là 7.733137074991366
# ----- Đang dự đoán cho dòng thứ 354 là 8.170219981729755
# ----- Đang dự đoán cho dòng thứ 355 là 7.138262546514104
# ----- Đang dự đoán cho dòng thứ 356 là 7.966666666666666
# ----- Đang dự đoán cho dòng thứ 357 là 7.5
# ----- Đang dự đoán cho dòng thứ 358 là 8.5
# ----- Đang dự đoán cho dòng thứ 359 là 7.285714285714286
# ----- Đang dự đoán cho dòng thứ 360 là 10.0
# ----- Đang dự đoán cho dòng thứ 361 là 8.3
# ----- Đang dự đoán cho dòng thứ 362 là 7.6
# ----- Đang dự đoán cho dòng thứ 363 là 7.799001521391831
# ----- Đang dự đoán cho dòng thứ 364 là 8.397774877234403
# ----- Đang dự đoán cho dòng thứ 365 là 7.9
# ----- Đang dự đoán cho dòng thứ 366 là 7.975000000000001
# ----- Đang dự đoán cho dòng thứ 367 là 7.0
# ----- Đang dự đoán cho dòng thứ 368 là 8.25
# ----- Đang dự đoán cho dòng thứ 369 là 9.0
# ----- Đang dự đoán cho dòng thứ 370 là 8.466666666666667
# ----- Đang dự đoán cho dòng thứ 371 là 8.671014670744299
# ----- Đang dự đoán cho dòng thứ 372 là 9.0
# ----- Đang dự đoán cho dòng thứ 373 là 7.6125
# ----- Đang dự đoán cho dòng thứ 374 là 7.480269815358541
# ----- Đang dự đoán cho dòng thứ 375 là 8.0
# ----- Đang dự đoán cho dòng thứ 376 là 7.0
# ----- Đang dự đoán cho dòng thứ 377 là 8.0
# ----- Đang dự đoán cho dòng thứ 378 là 7.2
# ----- Đang dự đoán cho dòng thứ 379 là 9.0
# ----- Đang dự đoán cho dòng thứ 380 là 6.0
# ----- Đang dự đoán cho dòng thứ 381 là 0
# ----- Đang dự đoán cho dòng thứ 382 là 7.856593713108482
# ----- Đang dự đoán cho dòng thứ 383 là 6.500404497436447
# ----- Đang dự đoán cho dòng thứ 384 là 9.0
# ----- Đang dự đoán cho dòng thứ 385 là 6.88
# ----- Đang dự đoán cho dòng thứ 386 là 9.0
# ----- Đang dự đoán cho dòng thứ 387 là 8.333333333333334
# ----- Đang dự đoán cho dòng thứ 388 là 8.533333333333333
# ----- Đang dự đoán cho dòng thứ 389 là 7.708620689655172
# ----- Đang dự đoán cho dòng thứ 390 là 8.23
# ----- Đang dự đoán cho dòng thứ 391 là 6.999240421648903
# ----- Đang dự đoán cho dòng thứ 392 là 6.825
# ----- Đang dự đoán cho dòng thứ 393 là 9.0
# ----- Đang dự đoán cho dòng thứ 394 là 7.266666666666667
# ----- Đang dự đoán cho dòng thứ 395 là 8.418181818181818
# ----- Đang dự đoán cho dòng thứ 396 là 7.3
# ----- Đang dự đoán cho dòng thứ 397 là 7.500000000000001
# ----- Đang dự đoán cho dòng thứ 398 là 8.125
# ----- Đang dự đoán cho dòng thứ 399 là 7.673333333333334
# ----- Đang dự đoán cho dòng thứ 400 là 7.422232399981396
# ----- Đang dự đoán cho dòng thứ 401 là 6.008385977446905
# ----- Đang dự đoán cho dòng thứ 402 là 0
# ----- Đang dự đoán cho dòng thứ 403 là 7.75
# ----- Đang dự đoán cho dòng thứ 404 là 6.0
# ----- Đang dự đoán cho dòng thứ 405 là 7.733333333333333
# ----- Đang dự đoán cho dòng thứ 406 là 10.0
# ----- Đang dự đoán cho dòng thứ 407 là 8.25073208621005
# ----- Đang dự đoán cho dòng thứ 408 là 7.852525252525253
# ----- Đang dự đoán cho dòng thứ 409 là 8.104761904761904
# ----- Đang dự đoán cho dòng thứ 410 là 8.47857142857143
# ----- Đang dự đoán cho dòng thứ 411 là 6.674990270939237
# ----- Đang dự đoán cho dòng thứ 412 là 5.666666666666667
# ----- Đang dự đoán cho dòng thứ 413 là 7.0
# ----- Đang dự đoán cho dòng thứ 414 là 7.0
# ----- Đang dự đoán cho dòng thứ 415 là 6.776564024091684
# ----- Đang dự đoán cho dòng thứ 416 là 0
# ----- Đang dự đoán cho dòng thứ 417 là 6.6
# ----- Đang dự đoán cho dòng thứ 418 là 8.557142857142857
# ----- Đang dự đoán cho dòng thứ 419 là 8.5
# ----- Đang dự đoán cho dòng thứ 420 là 7.435935250853329
# ----- Đang dự đoán cho dòng thứ 421 là 6.5
# ----- Đang dự đoán cho dòng thứ 422 là 0
# ----- Đang dự đoán cho dòng thứ 423 là 8.15
# ----- Đang dự đoán cho dòng thứ 424 là 7.784233504558357
# ----- Đang dự đoán cho dòng thứ 425 là 6.35
# ----- Đang dự đoán cho dòng thứ 426 là 7.0
# ----- Đang dự đoán cho dòng thứ 427 là 6.583333333333333
# ----- Đang dự đoán cho dòng thứ 428 là 0
# ----- Đang dự đoán cho dòng thứ 429 là 8.249926112861777
# ----- Đang dự đoán cho dòng thứ 430 là 9.0
# ----- Đang dự đoán cho dòng thứ 431 là 7.3
# ----- Đang dự đoán cho dòng thứ 432 là 8.000515165207505
# ----- Đang dự đoán cho dòng thứ 433 là 7.0
# ----- Đang dự đoán cho dòng thứ 434 là 9.0
# ----- Đang dự đoán cho dòng thứ 435 là 8.45
# ----- Đang dự đoán cho dòng thứ 436 là 6.6
# ----- Đang dự đoán cho dòng thứ 437 là 7.237754236283812
# ----- Đang dự đoán cho dòng thứ 438 là 8.185714285714287
# ----- Đang dự đoán cho dòng thứ 439 là 7.5
# ----- Đang dự đoán cho dòng thứ 440 là 8.73946441027999
# ----- Đang dự đoán cho dòng thứ 441 là 7.641176470588236
# ----- Đang dự đoán cho dòng thứ 442 là 4.0
# ----- Đang dự đoán cho dòng thứ 443 là 7.528571428571429
# ----- Đang dự đoán cho dòng thứ 444 là 9.34
# ----- Đang dự đoán cho dòng thứ 445 là 7.85
# ----- Đang dự đoán cho dòng thứ 446 là 6.0
# ----- Đang dự đoán cho dòng thứ 447 là 7.75
# ----- Đang dự đoán cho dòng thứ 448 là 4.937220958342598
# ----- Đang dự đoán cho dòng thứ 449 là 7.8
# ----- Đang dự đoán cho dòng thứ 450 là 6.925000000000001
# ----- Đang dự đoán cho dòng thứ 451 là 0
# ----- Đang dự đoán cho dòng thứ 452 là 8.612499999999999
# ----- Đang dự đoán cho dòng thứ 453 là 5.0
# ----- Đang dự đoán cho dòng thứ 454 là 8.6
# ----- Đang dự đoán cho dòng thứ 455 là 6.9360277495051035
# ----- Đang dự đoán cho dòng thứ 456 là 0
# ----- Đang dự đoán cho dòng thứ 457 là 7.972482373240835
# ----- Đang dự đoán cho dòng thứ 458 là 0
# ----- Đang dự đoán cho dòng thứ 459 là 8.333333333333334
# ----- Đang dự đoán cho dòng thứ 460 là 0
# ----- Đang dự đoán cho dòng thứ 461 là 3.5000000000000004
# ----- Đang dự đoán cho dòng thứ 462 là 7.721428571428571
# ----- Đang dự đoán cho dòng thứ 463 là 9.55
# ----- Đang dự đoán cho dòng thứ 464 là 7.76
# ----- Đang dự đoán cho dòng thứ 465 là 7.0
# ----- Đang dự đoán cho dòng thứ 466 là 7.649995437110305
# ----- Đang dự đoán cho dòng thứ 467 là 7.6
# ----- Đang dự đoán cho dòng thứ 468 là 7.574000000000001
# ----- Đang dự đoán cho dòng thứ 469 là 7.904999999999999
# ----- Đang dự đoán cho dòng thứ 470 là 8.333333333333334
# ----- Đang dự đoán cho dòng thứ 471 là 7.130183596310268
# ----- Đang dự đoán cho dòng thứ 472 là 7.4126887376393755
# ----- Đang dự đoán cho dòng thứ 473 là 7.123015490264453
# ----- Đang dự đoán cho dòng thứ 474 là 9.0
# ----- Đang dự đoán cho dòng thứ 475 là 6.916666666666667
# ----- Đang dự đoán cho dòng thứ 476 là 7.8
# ----- Đang dự đoán cho dòng thứ 477 là 0
# ----- Đang dự đoán cho dòng thứ 478 là 7.300000000000001
# ----- Đang dự đoán cho dòng thứ 479 là 6.425
# ----- Đang dự đoán cho dòng thứ 480 là 0
# ----- Đang dự đoán cho dòng thứ 481 là 8.2
# ----- Đang dự đoán cho dòng thứ 482 là 7.75
# ----- Đang dự đoán cho dòng thứ 483 là 5.5
# ----- Đang dự đoán cho dòng thứ 484 là 8.161702127659574
# ----- Đang dự đoán cho dòng thứ 485 là 6.0
# ----- Đang dự đoán cho dòng thứ 486 là 7.5
# ----- Đang dự đoán cho dòng thứ 487 là 6.825
# ----- Đang dự đoán cho dòng thứ 488 là 8.061136022472903
# ----- Đang dự đoán cho dòng thứ 489 là 8.2
# ----- Đang dự đoán cho dòng thứ 490 là 7.864558133949808
# ----- Đang dự đoán cho dòng thứ 491 là 7.440506765729666
# ----- Đang dự đoán cho dòng thứ 492 là 6.199999999999999
# ----- Đang dự đoán cho dòng thứ 493 là 7.690289458096907
# ----- Đang dự đoán cho dòng thứ 494 là 7.3
# ----- Đang dự đoán cho dòng thứ 495 là 1.0
# ----- Đang dự đoán cho dòng thứ 496 là 8.200510408598456
# ----- Đang dự đoán cho dòng thứ 497 là 5.5
# ----- Đang dự đoán cho dòng thứ 498 là 7.936441825851232
# ----- Đang dự đoán cho dòng thứ 499 là 7.580032626884675
# ----- Đang dự đoán cho dòng thứ 500 là 7.548914132555549
# ----- Đang dự đoán cho dòng thứ 501 là 8.0
# ----- Đang dự đoán cho dòng thứ 502 là 7.359999999999999
# ----- Đang dự đoán cho dòng thứ 503 là 7.134615384615385
# ----- Đang dự đoán cho dòng thứ 504 là 8.7
# ----- Đang dự đoán cho dòng thứ 505 là 7.596588170124871
# ----- Đang dự đoán cho dòng thứ 506 là 8.516666666666667
# ----- Đang dự đoán cho dòng thứ 507 là 8.833333333333334
# ----- Đang dự đoán cho dòng thứ 508 là 0
# ----- Đang dự đoán cho dòng thứ 509 là 7.0
# ----- Đang dự đoán cho dòng thứ 510 là 8.73238181441699
# ----- Đang dự đoán cho dòng thứ 511 là 9.5
# ----- Đang dự đoán cho dòng thứ 512 là 7.072491945852977
# ----- Đang dự đoán cho dòng thứ 513 là 7.688888888888889
# ----- Đang dự đoán cho dòng thứ 514 là 7.0
# ----- Đang dự đoán cho dòng thứ 515 là 9.5
# ----- Đang dự đoán cho dòng thứ 516 là 7.3805555555555555
# ----- Đang dự đoán cho dòng thứ 517 là 0
# ----- Đang dự đoán cho dòng thứ 518 là 9.0
# ----- Đang dự đoán cho dòng thứ 519 là 0
# ----- Đang dự đoán cho dòng thứ 520 là 8.3
# ----- Đang dự đoán cho dòng thứ 521 là 7.75
# ----- Đang dự đoán cho dòng thứ 522 là 4.95
# ----- Đang dự đoán cho dòng thứ 523 là 5.0
# ----- Đang dự đoán cho dòng thứ 524 là 8.0
# ----- Đang dự đoán cho dòng thứ 525 là 5.666666666666667
# ----- Đang dự đoán cho dòng thứ 526 là 0
# ----- Đang dự đoán cho dòng thứ 527 là 9.3625
# ----- Đang dự đoán cho dòng thứ 528 là 7.431428571428572
# ----- Đang dự đoán cho dòng thứ 529 là 7.0
# ----- Đang dự đoán cho dòng thứ 530 là 7.802212345971784
# ----- Đang dự đoán cho dòng thứ 531 là 8.15
# ----- Đang dự đoán cho dòng thứ 532 là 8.4
# ----- Đang dự đoán cho dòng thứ 533 là 6.9363612482713375
# ----- Đang dự đoán cho dòng thứ 534 là 9.0
# ----- Đang dự đoán cho dòng thứ 535 là 5.9693871043714
# ----- Đang dự đoán cho dòng thứ 536 là 8.75
# ----- Đang dự đoán cho dòng thứ 537 là 0
# ----- Đang dự đoán cho dòng thứ 538 là 8.5
# ----- Đang dự đoán cho dòng thứ 539 là 7.64290511354471
# ----- Đang dự đoán cho dòng thứ 540 là 7.38235822527587
# ----- Đang dự đoán cho dòng thứ 541 là 8.010993102578555
# ----- Đang dự đoán cho dòng thứ 542 là 8.0
# ----- Đang dự đoán cho dòng thứ 543 là 7.709259259259259
# ----- Đang dự đoán cho dòng thứ 544 là 7.587762622919079
# ----- Đang dự đoán cho dòng thứ 545 là 7.233333333333333
# ----- Đang dự đoán cho dòng thứ 546 là 8.5
# ----- Đang dự đoán cho dòng thứ 547 là 6.0
# ----- Đang dự đoán cho dòng thứ 548 là 7.743209876543211
# ----- Đang dự đoán cho dòng thứ 549 là 7.1
# ----- Đang dự đoán cho dòng thứ 550 là 0
# ----- Đang dự đoán cho dòng thứ 551 là 7.699999999999998
# ----- Đang dự đoán cho dòng thứ 552 là 7.726262626262626
# ----- Đang dự đoán cho dòng thứ 553 là 8.0
# ----- Đang dự đoán cho dòng thứ 554 là 8.706066166573322
# ----- Đang dự đoán cho dòng thứ 555 là 7.5570464447715695
# ----- Đang dự đoán cho dòng thứ 556 là 7.375
# ----- Đang dự đoán cho dòng thứ 557 là 7.3
# ----- Đang dự đoán cho dòng thứ 558 là 8.3
# ----- Đang dự đoán cho dòng thứ 559 là 7.4415546752493045
# ----- Đang dự đoán cho dòng thứ 560 là 4.666666666666667
# ----- Đang dự đoán cho dòng thứ 561 là 7.877422431159717
# ----- Đang dự đoán cho dòng thứ 562 là 7.2851676112771475
# ----- Đang dự đoán cho dòng thứ 563 là 7.382657806199311
# ----- Đang dự đoán cho dòng thứ 564 là 0
# ----- Đang dự đoán cho dòng thứ 565 là 9.0
# ----- Đang dự đoán cho dòng thứ 566 là 6.0
# ----- Đang dự đoán cho dòng thứ 567 là 8.125
# ----- Đang dự đoán cho dòng thứ 568 là 7.0
# ----- Đang dự đoán cho dòng thứ 569 là 4.0
# ----- Đang dự đoán cho dòng thứ 570 là 0
# ----- Đang dự đoán cho dòng thứ 571 là 8.214285714285714
# ----- Đang dự đoán cho dòng thứ 572 là 7.165620382762229
# ----- Đang dự đoán cho dòng thứ 573 là 6.9
# ----- Đang dự đoán cho dòng thứ 574 là 8.5
# ----- Đang dự đoán cho dòng thứ 575 là 7.088888888888889
# ----- Đang dự đoán cho dòng thứ 576 là 6.540000000000001
# ----- Đang dự đoán cho dòng thứ 577 là 0
# ----- Đang dự đoán cho dòng thứ 578 là 7.428571428571429
# ----- Đang dự đoán cho dòng thứ 579 là 9.1
# ----- Đang dự đoán cho dòng thứ 580 là 8.5
# ----- Đang dự đoán cho dòng thứ 581 là 6.811111111111111
# ----- Đang dự đoán cho dòng thứ 582 là 0
# ----- Đang dự đoán cho dòng thứ 583 là 7.96875
# ----- Đang dự đoán cho dòng thứ 584 là 7.69964311793822
# ----- Đang dự đoán cho dòng thứ 585 là 8.09
# ----- Đang dự đoán cho dòng thứ 586 là 0
# ----- Đang dự đoán cho dòng thứ 587 là 0
# ----- Đang dự đoán cho dòng thứ 588 là 7.5625
# ----- Đang dự đoán cho dòng thứ 589 là 9.1
# ----- Đang dự đoán cho dòng thứ 590 là 5.5
# ----- Đang dự đoán cho dòng thứ 591 là 7.35
# ----- Đang dự đoán cho dòng thứ 592 là 7.444444444444445
# ----- Đang dự đoán cho dòng thứ 593 là 7.728194103645369
# ----- Đang dự đoán cho dòng thứ 594 là 7.651724137931035
# ----- Đang dự đoán cho dòng thứ 595 là 10.0
# ----- Đang dự đoán cho dòng thứ 596 là 7.7
# ----- Đang dự đoán cho dòng thứ 597 là 0
# ----- Đang dự đoán cho dòng thứ 598 là 8.266666666666667
# ----- Đang dự đoán cho dòng thứ 599 là 5.8
# ----- Đang dự đoán cho dòng thứ 600 là 6.988888888888889
# ----- Đang dự đoán cho dòng thứ 601 là 7.748792427692448
# ----- Đang dự đoán cho dòng thứ 602 là 7.388888888888889
# ----- Đang dự đoán cho dòng thứ 603 là 0
# ----- Đang dự đoán cho dòng thứ 604 là 0
# ----- Đang dự đoán cho dòng thứ 605 là 8.1
# ----- Đang dự đoán cho dòng thứ 606 là 8.12051282051282
# ----- Đang dự đoán cho dòng thứ 607 là 8.25
# ----- Đang dự đoán cho dòng thứ 608 là 9.0
# ----- Đang dự đoán cho dòng thứ 609 là 7.499999999999999
# ----- Đang dự đoán cho dòng thứ 610 là 7.538789894577698
# ----- Đang dự đoán cho dòng thứ 611 là 7.75
# ----- Đang dự đoán cho dòng thứ 612 là 7.266666666666666
# ----- Đang dự đoán cho dòng thứ 613 là 7.0
# ----- Đang dự đoán cho dòng thứ 614 là 4.0
# ----- Đang dự đoán cho dòng thứ 615 là 6.3
# ----- Đang dự đoán cho dòng thứ 616 là 7.955555555555555
# ----- Đang dự đoán cho dòng thứ 617 là 0
# ----- Đang dự đoán cho dòng thứ 618 là 6.333333333333333
# ----- Đang dự đoán cho dòng thứ 619 là 0
# ----- Đang dự đoán cho dòng thứ 620 là 7.505172413793103
# ----- Đang dự đoán cho dòng thứ 621 là 6.775
# ----- Đang dự đoán cho dòng thứ 622 là 6.928571428571429
# ----- Đang dự đoán cho dòng thứ 623 là 7.709876543209877
# ----- Đang dự đoán cho dòng thứ 624 là 7.23125
# ----- Đang dự đoán cho dòng thứ 625 là 6.0
# ----- Đang dự đoán cho dòng thứ 626 là 7.0
# ----- Đang dự đoán cho dòng thứ 627 là 9.0
# ----- Đang dự đoán cho dòng thứ 628 là 8.477629612858395
# ----- Đang dự đoán cho dòng thứ 629 là 7.666666666666665
# ----- Đang dự đoán cho dòng thứ 630 là 7.133333333333334
# ----- Đang dự đoán cho dòng thứ 631 là 0
# ----- Đang dự đoán cho dòng thứ 632 là 5.1
# ----- Đang dự đoán cho dòng thứ 633 là 7.833333333333333
# ----- Đang dự đoán cho dòng thứ 634 là 9.0
# ----- Đang dự đoán cho dòng thứ 635 là 0
# ----- Đang dự đoán cho dòng thứ 636 là 7.97
# ----- Đang dự đoán cho dòng thứ 637 là 7.752941176470589
# ----- Đang dự đoán cho dòng thứ 638 là 8.152380952380952
# ----- Đang dự đoán cho dòng thứ 639 là 0
# ----- Đang dự đoán cho dòng thứ 640 là 6.909999999999999
# ----- Đang dự đoán cho dòng thứ 641 là 10.0
# ----- Đang dự đoán cho dòng thứ 642 là 7.279764405085784
# ----- Đang dự đoán cho dòng thứ 643 là 3.5
# ----- Đang dự đoán cho dòng thứ 644 là 7.216666666666668
# ----- Đang dự đoán cho dòng thứ 645 là 5.86
# ----- Đang dự đoán cho dòng thứ 646 là 6.0
# ----- Đang dự đoán cho dòng thứ 647 là 7.792105263157896
# ----- Đang dự đoán cho dòng thứ 648 là 8.8
# ----- Đang dự đoán cho dòng thứ 649 là 8.25
# ----- Đang dự đoán cho dòng thứ 650 là 8.333333333333334
# ----- Đang dự đoán cho dòng thứ 651 là 7.625
# ----- Đang dự đoán cho dòng thứ 652 là 9.85
# ----- Đang dự đoán cho dòng thứ 653 là 7.17906976744186
# ----- Đang dự đoán cho dòng thứ 654 là 7.5
# ----- Đang dự đoán cho dòng thứ 655 là 8.0
# ----- Đang dự đoán cho dòng thứ 656 là 8.5
# ----- Đang dự đoán cho dòng thứ 657 là 7.283333333333332
# ----- Đang dự đoán cho dòng thứ 658 là 7.451301790947913
# ----- Đang dự đoán cho dòng thứ 659 là 0
# ----- Đang dự đoán cho dòng thứ 660 là 0
# ----- Đang dự đoán cho dòng thứ 661 là 0
# ----- Đang dự đoán cho dòng thứ 662 là 0
# ----- Đang dự đoán cho dòng thứ 663 là 6.1000000000000005
# ----- Đang dự đoán cho dòng thứ 664 là 7.465616698331071
# ----- Đang dự đoán cho dòng thứ 665 là 6.833333333333333
# ----- Đang dự đoán cho dòng thứ 666 là 7.933333333333334
# ----- Đang dự đoán cho dòng thứ 667 là 9.5
# ----- Đang dự đoán cho dòng thứ 668 là 7.253659284768424
# ----- Đang dự đoán cho dòng thứ 669 là 6.0
# ----- Đang dự đoán cho dòng thứ 670 là 7.358175104000348
# ----- Đang dự đoán cho dòng thứ 671 là 7.6000000000000005
# ----- Đang dự đoán cho dòng thứ 672 là 8.244003619499916
# ----- Đang dự đoán cho dòng thứ 673 là 0
# ----- Đang dự đoán cho dòng thứ 674 là 10.0
# ----- Đang dự đoán cho dòng thứ 675 là 7.823809523809524
# ----- Đang dự đoán cho dòng thứ 676 là 7.396141549609559
# ----- Đang dự đoán cho dòng thứ 677 là 7.0
# ----- Đang dự đoán cho dòng thứ 678 là 8.39090909090909
# ----- Đang dự đoán cho dòng thứ 679 là 7.6891891891891895
# ----- Đang dự đoán cho dòng thứ 680 là 6.3
# ----- Đang dự đoán cho dòng thứ 681 là 7.0
# ----- Đang dự đoán cho dòng thứ 682 là 0
# ----- Đang dự đoán cho dòng thứ 683 là 8.5
# ----- Đang dự đoán cho dòng thứ 684 là 0
# ----- Đang dự đoán cho dòng thứ 685 là 7.3
# ----- Đang dự đoán cho dòng thứ 686 là 8.5
# ----- Đang dự đoán cho dòng thứ 687 là 8.5
# ----- Đang dự đoán cho dòng thứ 688 là 8.0
# ----- Đang dự đoán cho dòng thứ 689 là 0
# ----- Đang dự đoán cho dòng thứ 690 là 0
# ----- Đang dự đoán cho dòng thứ 691 là 9.0
# ----- Đang dự đoán cho dòng thứ 692 là 7.077777777777778
# ----- Đang dự đoán cho dòng thứ 693 là 7.757142857142857
# ----- Đang dự đoán cho dòng thứ 694 là 9.0
# ----- Đang dự đoán cho dòng thứ 695 là 5.0
# ----- Đang dự đoán cho dòng thứ 696 là 9.0
# ----- Đang dự đoán cho dòng thứ 697 là 7.719317104246643
# ----- Đang dự đoán cho dòng thứ 698 là 0
# ----- Đang dự đoán cho dòng thứ 699 là 8.0
# ----- Đang dự đoán cho dòng thứ 700 là 7.359999999999999
# ----- Đang dự đoán cho dòng thứ 701 là 0
# ----- Đang dự đoán cho dòng thứ 702 là 8.311111111111112
# ----- Đang dự đoán cho dòng thứ 703 là 7.45
# ----- Đang dự đoán cho dòng thứ 704 là 0
# ----- Đang dự đoán cho dòng thứ 705 là 7.412799671178515
# ----- Đang dự đoán cho dòng thứ 706 là 0
# ----- Đang dự đoán cho dòng thứ 707 là 8.165789473684208
# ----- Đang dự đoán cho dòng thứ 708 là 10.0
# ----- Đang dự đoán cho dòng thứ 709 là 8.725
# ----- Đang dự đoán cho dòng thứ 710 là 7.357142857142857
# ----- Đang dự đoán cho dòng thứ 711 là 7.490909090909091
# ----- Đang dự đoán cho dòng thứ 712 là 0
# ----- Đang dự đoán cho dòng thứ 713 là 7.0
# ----- Đang dự đoán cho dòng thứ 714 là 7.792732881805373
# ----- Đang dự đoán cho dòng thứ 715 là 8.5
# ----- Đang dự đoán cho dòng thứ 716 là 7.938152959303621
# ----- Đang dự đoán cho dòng thứ 717 là 7.25
# ----- Đang dự đoán cho dòng thứ 718 là 7.35
# ----- Đang dự đoán cho dòng thứ 719 là 8.666666666666666
# ----- Đang dự đoán cho dòng thứ 720 là 7.7333333333333325
# ----- Đang dự đoán cho dòng thứ 721 là 8.657894736842104
# ----- Đang dự đoán cho dòng thứ 722 là 0
# ----- Đang dự đoán cho dòng thứ 723 là 8.875
# ----- Đang dự đoán cho dòng thứ 724 là 10.0
# ----- Đang dự đoán cho dòng thứ 725 là 7.957142857142857
# ----- Đang dự đoán cho dòng thứ 726 là 9.166666666666666
# ----- Đang dự đoán cho dòng thứ 727 là 0
# ----- Đang dự đoán cho dòng thứ 728 là 7.476858030740425
# ----- Đang dự đoán cho dòng thứ 729 là 6.666666666666667
# ----- Đang dự đoán cho dòng thứ 730 là 7.7185185185185174
# ----- Đang dự đoán cho dòng thứ 731 là 6.76
# ----- Đang dự đoán cho dòng thứ 732 là 8.0
# ----- Đang dự đoán cho dòng thứ 733 là 7.44
# ----- Đang dự đoán cho dòng thứ 734 là 7.6921875
# ----- Đang dự đoán cho dòng thứ 735 là 7.6000000000000005
# ----- Đang dự đoán cho dòng thứ 736 là 7.340541015699331
# ----- Đang dự đoán cho dòng thứ 737 là 7.954166666666667
# ----- Đang dự đoán cho dòng thứ 738 là 7.698059765678335
# ----- Đang dự đoán cho dòng thứ 739 là 0
# ----- Đang dự đoán cho dòng thứ 740 là 4.012316785623333
# ----- Đang dự đoán cho dòng thứ 741 là 8.142857142857142
# ----- Đang dự đoán cho dòng thứ 742 là 5.65
# ----- Đang dự đoán cho dòng thứ 743 là 8.300268944260797
# ----- Đang dự đoán cho dòng thứ 744 là 8.540816298783437
# ----- Đang dự đoán cho dòng thứ 745 là 6.5
# ----- Đang dự đoán cho dòng thứ 746 là 6.0
# ----- Đang dự đoán cho dòng thứ 747 là 0
# ----- Đang dự đoán cho dòng thứ 748 là 7.456860836130237
# ----- Đang dự đoán cho dòng thứ 749 là 5.2
# ----- Đang dự đoán cho dòng thứ 750 là 6.699999999999999
# ----- Đang dự đoán cho dòng thứ 751 là 6.894117647058824
# ----- Đang dự đoán cho dòng thứ 752 là 8.5
# ----- Đang dự đoán cho dòng thứ 753 là 8.083333333333334
# ----- Đang dự đoán cho dòng thứ 754 là 7.814
# ----- Đang dự đoán cho dòng thứ 755 là 0
# ----- Đang dự đoán cho dòng thứ 756 là 7.040086310251137
# ----- Đang dự đoán cho dòng thứ 757 là 7.5694647732564615
# ----- Đang dự đoán cho dòng thứ 758 là 5.9250198599061825
# ----- Đang dự đoán cho dòng thứ 759 là 7.4
# ----- Đang dự đoán cho dòng thứ 760 là 0
# ----- Đang dự đoán cho dòng thứ 761 là 6.375
# ----- Đang dự đoán cho dòng thứ 762 là 6.6
# ----- Đang dự đoán cho dòng thứ 763 là 7.635144560793125
# ----- Đang dự đoán cho dòng thứ 764 là 7.503882235014288
# ----- Đang dự đoán cho dòng thứ 765 là 8.25
# ----- Đang dự đoán cho dòng thứ 766 là 7.975123271805885
# ----- Đang dự đoán cho dòng thứ 767 là 7.738095238095238
# ----- Đang dự đoán cho dòng thứ 768 là 8.36
# ----- Đang dự đoán cho dòng thứ 769 là 8.5760101047936
# ----- Đang dự đoán cho dòng thứ 770 là 7.5237288135593205
# ----- Đang dự đoán cho dòng thứ 771 là 8.08
# ----- Đang dự đoán cho dòng thứ 772 là 7.822222222222221
# ----- Đang dự đoán cho dòng thứ 773 là 7.77659754531299
# ----- Đang dự đoán cho dòng thứ 774 là 6.5
# ----- Đang dự đoán cho dòng thứ 775 là 0
# ----- Đang dự đoán cho dòng thứ 776 là 8.5
# ----- Đang dự đoán cho dòng thứ 777 là 8.92
# ----- Đang dự đoán cho dòng thứ 778 là 7.9
# ----- Đang dự đoán cho dòng thứ 779 là 7.6891891891891895
# ----- Đang dự đoán cho dòng thứ 780 là 7.55
# ----- Đang dự đoán cho dòng thứ 781 là 9.0
# ----- Đang dự đoán cho dòng thứ 782 là 7.739999999999999
# ----- Đang dự đoán cho dòng thứ 783 là 0
# ----- Đang dự đoán cho dòng thứ 784 là 0
# ----- Đang dự đoán cho dòng thứ 785 là 8.666666666666666
# ----- Đang dự đoán cho dòng thứ 786 là 7.549636103486362
# ----- Đang dự đoán cho dòng thứ 787 là 7.905172760014227
# ----- Đang dự đoán cho dòng thứ 788 là 8.026666666666667
# ----- Đang dự đoán cho dòng thứ 789 là 10.0
# ----- Đang dự đoán cho dòng thứ 790 là 7.1
# ----- Đang dự đoán cho dòng thứ 791 là 7.340000000000001
# ----- Đang dự đoán cho dòng thứ 792 là 9.5
# ----- Đang dự đoán cho dòng thứ 793 là 7.851395033662719
# ----- Đang dự đoán cho dòng thứ 794 là 5.959999999999999
# ----- Đang dự đoán cho dòng thứ 795 là 8.04176284660491
# ----- Đang dự đoán cho dòng thứ 796 là 8.0
# ----- Đang dự đoán cho dòng thứ 797 là 6.885714285714286
# ----- Đang dự đoán cho dòng thứ 798 là 8.0
# ----- Đang dự đoán cho dòng thứ 799 là 5.971428571428571
# ----- Đang dự đoán cho dòng thứ 800 là 8.5
# ----- Đang dự đoán cho dòng thứ 801 là 9.15
# ----- Đang dự đoán cho dòng thứ 802 là 5.728571428571429
# ----- Đang dự đoán cho dòng thứ 803 là 3.5
# ----- Đang dự đoán cho dòng thứ 804 là 0
# ----- Đang dự đoán cho dòng thứ 805 là 7.05
# ----- Đang dự đoán cho dòng thứ 806 là 6.606361644360951
# ----- Đang dự đoán cho dòng thứ 807 là 6.133443349056531
# ----- Đang dự đoán cho dòng thứ 808 là 7.471428571428571
# ----- Đang dự đoán cho dòng thứ 809 là 5.1
# ----- Đang dự đoán cho dòng thứ 810 là 8.483870967741936
# ----- Đang dự đoán cho dòng thứ 811 là 0
# ----- Đang dự đoán cho dòng thứ 812 là 7.866666666666667
# ----- Đang dự đoán cho dòng thứ 813 là 9.174973301568325
# ----- Đang dự đoán cho dòng thứ 814 là 10.0
# ----- Đang dự đoán cho dòng thứ 815 là 7.380555555555556
# ----- Đang dự đoán cho dòng thứ 816 là 4.7
# ----- Đang dự đoán cho dòng thứ 817 là 7.928571428571429
# ----- Đang dự đoán cho dòng thứ 818 là 0
# ----- Đang dự đoán cho dòng thứ 819 là 7.6
# ----- Đang dự đoán cho dòng thứ 820 là 7.952951358841709
# ----- Đang dự đoán cho dòng thứ 821 là 8.0
# ----- Đang dự đoán cho dòng thứ 822 là 5.8999999999999995
# ----- Đang dự đoán cho dòng thứ 823 là 7.476606573694462
# ----- Đang dự đoán cho dòng thứ 824 là 3.5
# ----- Đang dự đoán cho dòng thứ 825 là 9.1
# ----- Đang dự đoán cho dòng thứ 826 là 0
# ----- Đang dự đoán cho dòng thứ 827 là 0
# ----- Đang dự đoán cho dòng thứ 828 là 7.864705882352941
# ----- Đang dự đoán cho dòng thứ 829 là 7.611111111111111
# ----- Đang dự đoán cho dòng thứ 830 là 0
# ----- Đang dự đoán cho dòng thứ 831 là 0
# ----- Đang dự đoán cho dòng thứ 832 là 8.6
# ----- Đang dự đoán cho dòng thứ 833 là 7.533333333333335
# ----- Đang dự đoán cho dòng thứ 834 là 8.05
# ----- Đang dự đoán cho dòng thứ 835 là 7.625893157585298
# ----- Đang dự đoán cho dòng thứ 836 là 7.3
# ----- Đang dự đoán cho dòng thứ 837 là 7.5
# ----- Đang dự đoán cho dòng thứ 838 là 8.0
# ----- Đang dự đoán cho dòng thứ 839 là 8.299999999999999
# ----- Đang dự đoán cho dòng thứ 840 là 0
# ----- Đang dự đoán cho dòng thứ 841 là 7.8428571428571425
# ----- Đang dự đoán cho dòng thứ 842 là 7.449999999999999
# ----- Đang dự đoán cho dòng thứ 843 là 7.765509094432354
# ----- Đang dự đoán cho dòng thứ 844 là 9.233333333333333
# ----- Đang dự đoán cho dòng thứ 845 là 8.8
# ----- Đang dự đoán cho dòng thứ 846 là 6.720000000000001
# ----- Đang dự đoán cho dòng thứ 847 là 0
# ----- Đang dự đoán cho dòng thứ 848 là 7.25
# ----- Đang dự đoán cho dòng thứ 849 là 8.32258064516129
# ----- Đang dự đoán cho dòng thứ 850 là 8.875
# ----- Đang dự đoán cho dòng thứ 851 là 6.2
# ----- Đang dự đoán cho dòng thứ 852 là 8.6092343590066
# ----- Đang dự đoán cho dòng thứ 853 là 3.0
# ----- Đang dự đoán cho dòng thứ 854 là 7.855555555555556
# ----- Đang dự đoán cho dòng thứ 855 là 0
# ----- Đang dự đoán cho dòng thứ 856 là 6.0
# ----- Đang dự đoán cho dòng thứ 857 là 7.781185580283985
# ----- Đang dự đoán cho dòng thứ 858 là 0
# ----- Đang dự đoán cho dòng thứ 859 là 9.5
# ----- Đang dự đoán cho dòng thứ 860 là 7.155555555555556
# ----- Đang dự đoán cho dòng thứ 861 là 10.0
# ----- Đang dự đoán cho dòng thứ 862 là 9.0
# ----- Đang dự đoán cho dòng thứ 863 là 7.957142857142857
# ----- Đang dự đoán cho dòng thứ 864 là 10.0
# ----- Đang dự đoán cho dòng thứ 865 là 8.102320617292088
# ----- Đang dự đoán cho dòng thứ 866 là 4.8999999999999995
# ----- Đang dự đoán cho dòng thứ 867 là 7.721176470588236
# ----- Đang dự đoán cho dòng thứ 868 là 7.016666666666666
# ----- Đang dự đoán cho dòng thứ 869 là 7.961143094092655
# ----- Đang dự đoán cho dòng thứ 870 là 7.74857142857143
# ----- Đang dự đoán cho dòng thứ 871 là 8.702723690499543
# ----- Đang dự đoán cho dòng thứ 872 là 7.537695419163193
# ----- Đang dự đoán cho dòng thứ 873 là 6.05
# ----- Đang dự đoán cho dòng thứ 874 là 7.525
# ----- Đang dự đoán cho dòng thứ 875 là 0
# ----- Đang dự đoán cho dòng thứ 876 là 7.401553601402348
# ----- Đang dự đoán cho dòng thứ 877 là 1.0
# ----- Đang dự đoán cho dòng thứ 878 là 7.550980392156863
# ----- Đang dự đoán cho dòng thứ 879 là 0
# ----- Đang dự đoán cho dòng thứ 880 là 6.7
# ----- Đang dự đoán cho dòng thứ 881 là 6.88
# ----- Đang dự đoán cho dòng thứ 882 là 6.6
# ----- Đang dự đoán cho dòng thứ 883 là 7.65
# ----- Đang dự đoán cho dòng thứ 884 là 7.238461538461539
# ----- Đang dự đoán cho dòng thứ 885 là 7.959999999999999
# ----- Đang dự đoán cho dòng thứ 886 là 8.0
# ----- Đang dự đoán cho dòng thứ 887 là 10.0
# ----- Đang dự đoán cho dòng thứ 888 là 9.0
# ----- Đang dự đoán cho dòng thứ 889 là 6.932040935422875
# ----- Đang dự đoán cho dòng thứ 890 là 8.799999999999999
# ----- Đang dự đoán cho dòng thứ 891 là 6.9284748705426775
# ----- Đang dự đoán cho dòng thứ 892 là 7.550980392156863
# ----- Đang dự đoán cho dòng thứ 893 là 8.168292682926829
# ----- Đang dự đoán cho dòng thứ 894 là 6.5
# ----- Đang dự đoán cho dòng thứ 895 là 7.804545454545454
# ----- Đang dự đoán cho dòng thứ 896 là 7.666666666666667
# ----- Đang dự đoán cho dòng thứ 897 là 8.0
# ----- Đang dự đoán cho dòng thứ 898 là 7.579775280898876
# ----- Đang dự đoán cho dòng thứ 899 là 7.25
# ----- Đang dự đoán cho dòng thứ 900 là 9.5
# ----- Đang dự đoán cho dòng thứ 901 là 6.6618795221253
# ----- Đang dự đoán cho dòng thứ 902 là 6.828503210463105
# ----- Đang dự đoán cho dòng thứ 903 là 7.486924146406352
# ----- Đang dự đoán cho dòng thứ 904 là 7.473683915286501
# ----- Đang dự đoán cho dòng thứ 905 là 6.6
# ----- Đang dự đoán cho dòng thứ 906 là 7.666666666666667
# ----- Đang dự đoán cho dòng thứ 907 là 9.4
# ----- Đang dự đoán cho dòng thứ 908 là 9.0
# ----- Đang dự đoán cho dòng thứ 909 là 8.02863501274887
# ----- Đang dự đoán cho dòng thứ 910 là 7.4125
# ----- Đang dự đoán cho dòng thứ 911 là 0
# ----- Đang dự đoán cho dòng thứ 912 là 0
# ----- Đang dự đoán cho dòng thứ 913 là 7.558053815355789
# ----- Đang dự đoán cho dòng thứ 914 là 0
# ----- Đang dự đoán cho dòng thứ 915 là 0
# ----- Đang dự đoán cho dòng thứ 916 là 6.0
# ----- Đang dự đoán cho dòng thứ 917 là 7.5
# ----- Đang dự đoán cho dòng thứ 918 là 8.5
# ----- Đang dự đoán cho dòng thứ 919 là 8.619991878140759
# ----- Đang dự đoán cho dòng thứ 920 là 7.716948540787376
# ----- Đang dự đoán cho dòng thứ 921 là 7.6
# ----- Đang dự đoán cho dòng thứ 922 là 6.842857142857142
# ----- Đang dự đoán cho dòng thứ 923 là 7.716666666666667
# ----- Đang dự đoán cho dòng thứ 924 là 7.0
# ----- Đang dự đoán cho dòng thứ 925 là 7.24
# ----- Đang dự đoán cho dòng thứ 926 là 8.8
# ----- Đang dự đoán cho dòng thứ 927 là 9.0
# ----- Đang dự đoán cho dòng thứ 928 là 8.948447676265971
# ----- Đang dự đoán cho dòng thứ 929 là 7.8
# ----- Đang dự đoán cho dòng thứ 930 là 7.159999999999999
# ----- Đang dự đoán cho dòng thứ 931 là 7.0
# ----- Đang dự đoán cho dòng thứ 932 là 0
# ----- Đang dự đoán cho dòng thứ 933 là 7.666666666666667
# ----- Đang dự đoán cho dòng thứ 934 là 9.1
# ----- Đang dự đoán cho dòng thứ 935 là 0
# ----- Đang dự đoán cho dòng thứ 936 là 8.017391304347825
# ----- Đang dự đoán cho dòng thứ 937 là 7.631818181818181
# ----- Đang dự đoán cho dòng thứ 938 là 9.37142857142857
# ----- Đang dự đoán cho dòng thứ 939 là 7.0
# ----- Đang dự đoán cho dòng thứ 940 là 6.5
# ----- Đang dự đoán cho dòng thứ 941 là 5.928571428571429
# ----- Đang dự đoán cho dòng thứ 942 là 0
# ----- Đang dự đoán cho dòng thứ 943 là 5.75
# ----- Đang dự đoán cho dòng thứ 944 là 6.0
# ----- Đang dự đoán cho dòng thứ 945 là 9.0
# ----- Đang dự đoán cho dòng thứ 946 là 7.05
# ----- Đang dự đoán cho dòng thứ 947 là 7.731077898953579
# ----- Đang dự đoán cho dòng thứ 948 là 7.299999999999999
# ----- Đang dự đoán cho dòng thứ 949 là 7.775
# ----- Đang dự đoán cho dòng thứ 950 là 6.77956352920156
# ----- Đang dự đoán cho dòng thứ 951 là 6.25
# ----- Đang dự đoán cho dòng thứ 952 là 8.079351671559031
# ----- Đang dự đoán cho dòng thứ 953 là 7.599991416073304
# ----- Đang dự đoán cho dòng thứ 954 là 7.833333333333333
# ----- Đang dự đoán cho dòng thứ 955 là 7.531034482758621
# ----- Đang dự đoán cho dòng thứ 956 là 8.07996435434846
# ----- Đang dự đoán cho dòng thứ 957 là 7.498271091842567
# ----- Đang dự đoán cho dòng thứ 958 là 8.133333333333333
# Tổng thời gian dự đoán: 92.0532962958018 minutes

# %%
X_test['X_test_pred_item_pearson'] = X_test_pred_item_pearson
X_test['X_test_pred_item_cosine'] = X_test_pred_item_cosine

# %% [markdown]
# ### Save prediction results

# %%
X_test.to_csv('X_test_ItemKNN.csv')

# %% [markdown]
# ## Evaluation

# %%
df_UserKNN = pd.read_csv('/content/X_test_UserKNN.csv')
df_UserKNN
# Out:
#      Unnamed: 0  userId  movieId  rating     timestamp  \
# 0          1621    5932      307    10.0  1.458000e+09
# 1          2605    2542      412    10.0  1.485994e+09
# 2          4890     944      301     6.0  1.543363e+09
# 3          2040    5857      228     8.0  1.472083e+09
# 4          5399    5885      139     6.6  1.553904e+09
# ..          ...     ...      ...     ...           ...
# 954        5365    5972      210     9.0  1.552867e+09
# 955       15687    5914      394     8.8  1.679098e+09
# 956        1896    5961      128     6.0  1.468109e+09
# 957        6694    6786       65     6.3  1.578442e+09
# 958        2045     934      549     8.5  1.472256e+09
#
#      X_test_pred_user_pearson  X_test_pred_user_cosine
# 0                         NaN                 7.643336
# 1                    9.392191                 8.802912
# 2                         NaN                 7.627967
# 3                    9.000000                 0.000000
# 4                    0.000000                 7.306552
# ..                        ...                      ...
# 954                  9.000000                 9.500318
# 955                  9.178430                 9.300489
# 956                  6.262999                 0.000000
# 957                  7.000000                 7.399552
# 958                       NaN                 8.321427
#
# [959 rows x 7 columns]

# %%
df_UserKNN['X_test_pred_user_pearson'] = df_UserKNN['X_test_pred_user_pearson'].fillna(0)
df_UserKNN
# Out:
#      Unnamed: 0  userId  movieId  rating     timestamp  \
# 0          1621    5932      307    10.0  1.458000e+09
# 1          2605    2542      412    10.0  1.485994e+09
# 2          4890     944      301     6.0  1.543363e+09
# 3          2040    5857      228     8.0  1.472083e+09
# 4          5399    5885      139     6.6  1.553904e+09
# ..          ...     ...      ...     ...           ...
# 954        5365    5972      210     9.0  1.552867e+09
# 955       15687    5914      394     8.8  1.679098e+09
# 956        1896    5961      128     6.0  1.468109e+09
# 957        6694    6786       65     6.3  1.578442e+09
# 958        2045     934      549     8.5  1.472256e+09
#
#      X_test_pred_user_pearson  X_test_pred_user_cosine
# 0                    0.000000                 7.643336
# 1                    9.392191                 8.802912
# 2                    0.000000                 7.627967
# 3                    9.000000                 0.000000
# 4                    0.000000                 7.306552
# ..                        ...                      ...
# 954                  9.000000                 9.500318
# 955                  9.178430                 9.300489
# 956                  6.262999                 0.000000
# 957                  7.000000                 7.399552
# 958                  0.000000                 8.321427
#
# [959 rows x 7 columns]

# %%
test_df = pd.DataFrame(data=df_UserKNN[['userId',	'movieId','rating']])
test_df = test_df.sort_values(['userId', 'rating'], ascending=True)
test_df
# Out:
#      userId  movieId  rating
# 446      70      402     7.0
# 381     100      395     1.0
# 614     100      425     6.0
# 740     100      465     8.0
# 800     126      220     6.9
# ..      ...      ...     ...
# 54    10594      404     5.7
# 162   10636       65    10.0
# 186   10636      253    10.0
# 725   10657      399    10.0
# 639   10659      150     8.4
#
# [959 rows x 3 columns]

# %%
top_k_df_UserKNN_pearson = pd.DataFrame(data=df_UserKNN[['userId',	'movieId', 'X_test_pred_user_pearson']])
top_k_df_UserKNN_pearson = top_k_df_UserKNN_pearson[top_k_df_UserKNN_pearson.X_test_pred_user_pearson > 7.5]
top_k_df_UserKNN_pearson = top_k_df_UserKNN_pearson.sort_values(['userId', 'X_test_pred_user_pearson'], ascending=True)
top_k_df_UserKNN_pearson
# Out:
#      userId  movieId  X_test_pred_user_pearson
# 740     100      465                 10.000000
# 800     126      220                  7.655451
# 229     145      381                  8.000000
# 819     145      426                 10.000000
# 814     463      420                  8.950000
# ..      ...      ...                       ...
# 915   10249      561                  9.587509
# 873   10254      430                  8.407950
# 526   10266      412                  9.467005
# 364   10516      222                  8.232221
# 186   10636      253                  9.641085
#
# [405 rows x 3 columns]

# %%
from recommenders.evaluation.python_evaluation import auc, map_at_k, ndcg_at_k, precision_at_k, recall_at_k
def ranking_metrics(
    data_true,
    data_pred,
    K
):

    eval_map = map_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                    col_rating="rating", col_prediction="X_test_pred_user_pearson",
                    relevancy_method="top_k", k= K)

    eval_ndcg_5 = ndcg_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                      col_rating="rating", col_prediction="X_test_pred_user_pearson",
                      relevancy_method="top_k", k= 5)

    eval_ndcg_10 = ndcg_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                      col_rating="rating", col_prediction="X_test_pred_user_pearson",
                      relevancy_method="top_k", k= K)

    eval_precision_10 = precision_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                               col_rating="rating", col_prediction="X_test_pred_user_pearson",
                               relevancy_method="top_k", k= K)

    eval_precision_5 = precision_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                               col_rating="rating", col_prediction="X_test_pred_user_pearson",
                               relevancy_method="top_k", k= 5)

    eval_recall_10 = recall_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                          col_rating="rating", col_prediction="X_test_pred_user_pearson",
                          relevancy_method="top_k", k= K)

    eval_recall_5 = recall_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                          col_rating="rating", col_prediction="X_test_pred_user_pearson",
                          relevancy_method="top_k", k= 5)


    df_result = pd.DataFrame(
        {
            "MAP": eval_map,
            "nDCG@10": eval_ndcg_10,
            "nDCG@5": eval_ndcg_5,
            "Precision@10": eval_precision_10,
            "Precision@5": eval_precision_5,
            "Recall@10": eval_recall_10,
            "Recall@5": eval_recall_5,
        },
        index=[0]
    )

    return df_result

# %%
df = df.rename(columns={'IDuser': "userId", 'IDhotel': "movieId", 'Rating': "rating"})

# %% [markdown]
# ### top_k_df_UserKNN_pearson

# %%
eval = ranking_metrics(
    data_true=df,
    data_pred=top_k_df_UserKNN_pearson,
    K=10
)

eval
# Out:
#         MAP   nDCG@10    nDCG@5  Precision@10  Precision@5  Recall@10  \
# 0  0.192579  0.010229  0.013837      0.192609     0.362609   0.178047
#
#    Recall@5
# 0  0.176776

# %%
top_k_df_UserKNN_cosine = pd.DataFrame(data=df_UserKNN[['userId',	'movieId', 'X_test_pred_user_cosine']])
top_k_df_UserKNN_cosine = top_k_df_UserKNN_cosine[top_k_df_UserKNN_cosine.X_test_pred_user_cosine > 7.5]
top_k_df_UserKNN_cosine = top_k_df_UserKNN_cosine.sort_values(['userId', 'X_test_pred_user_cosine'], ascending=True)
top_k_df_UserKNN_cosine
# Out:
#      userId  movieId  X_test_pred_user_cosine
# 446      70      402                 8.444917
# 740     100      465                 7.615357
# 800     126      220                 7.902097
# 933     415      515                 7.583615
# 814     463      420                 7.659743
# ..      ...      ...                      ...
# 873   10254      430                 7.676133
# 526   10266      412                 8.835199
# 364   10516      222                 7.579740
# 768   10516      383                 8.987949
# 186   10636      253                 8.625000
#
# [500 rows x 3 columns]

# %%
from recommenders.evaluation.python_evaluation import auc, map_at_k, ndcg_at_k, precision_at_k, recall_at_k
def ranking_metrics(
    data_true,
    data_pred,
    K
):

    eval_map = map_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                    col_rating="rating", col_prediction="X_test_pred_user_cosine",
                    relevancy_method="top_k", k= K)

    eval_ndcg_5 = ndcg_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                      col_rating="rating", col_prediction="X_test_pred_user_cosine",
                      relevancy_method="top_k", k= 5)

    eval_ndcg_10 = ndcg_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                      col_rating="rating", col_prediction="X_test_pred_user_cosine",
                      relevancy_method="top_k", k= K)

    eval_precision_10 = precision_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                               col_rating="rating", col_prediction="X_test_pred_user_cosine",
                               relevancy_method="top_k", k= K)

    eval_precision_5 = precision_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                               col_rating="rating", col_prediction="X_test_pred_user_cosine",
                               relevancy_method="top_k", k= 5)

    eval_recall_10 = recall_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                          col_rating="rating", col_prediction="X_test_pred_user_cosine",
                          relevancy_method="top_k", k= K)

    eval_recall_5 = recall_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                          col_rating="rating", col_prediction="X_test_pred_user_cosine",
                          relevancy_method="top_k", k= 5)

    df_result = pd.DataFrame(
        {
            "MAP": eval_map,
            "nDCG@10": eval_ndcg_10,
            "nDCG@5": eval_ndcg_5,
            "Precision@10": eval_precision_10,
            "Precision@5": eval_precision_5,
            "Recall@10": eval_recall_10,
            "Recall@5": eval_recall_5,
        },
        index=[0]
    )

    return df_result

# %% [markdown]
# ### top_k_df_UserKNN_cosine

# %%
eval = ranking_metrics(
    data_true=df,
    data_pred=top_k_df_UserKNN_cosine,
    K=10
)

eval
# Out:
#         MAP   nDCG@10    nDCG@5  Precision@10  Precision@5  Recall@10  \
# 0  0.215113  0.013535  0.017615      0.195804     0.367832   0.198342
#
#    Recall@5
# 0  0.197116

# %%
df_ItemKNN = pd.read_csv('/content/X_test_ItemKNN.csv')
df_ItemKNN
# Out:
#      Unnamed: 0  userId  movieId  rating     timestamp  \
# 0          1621    5932      307    10.0  1.458000e+09
# 1          2605    2542      412    10.0  1.485994e+09
# 2          4890     944      301     6.0  1.543363e+09
# 3          2040    5857      228     8.0  1.472083e+09
# 4          5399    5885      139     6.6  1.553904e+09
# ..          ...     ...      ...     ...           ...
# 954        5365    5972      210     9.0  1.552867e+09
# 955       15687    5914      394     8.8  1.679098e+09
# 956        1896    5961      128     6.0  1.468109e+09
# 957        6694    6786       65     6.3  1.578442e+09
# 958        2045     934      549     8.5  1.472256e+09
#
#      X_test_pred_item_pearson  X_test_pred_item_cosine
# 0                    7.682527                 8.338462
# 1                    7.296643                 0.000000
# 2                    7.000000                 7.875000
# 3                    6.312835                 8.014583
# 4                    0.000000                 8.500944
# ..                        ...                      ...
# 954                  8.125247                 7.833333
# 955                  8.799790                 7.531034
# 956                  9.000000                 8.079964
# 957                       NaN                 7.498271
# 958                  0.000000                 8.133333
#
# [959 rows x 7 columns]

# %%
df_ItemKNN['X_test_pred_item_pearson'] = df_ItemKNN['X_test_pred_item_pearson'].fillna(0)
df_ItemKNN
# Out:
#      Unnamed: 0  userId  movieId  rating     timestamp  \
# 0          1621    5932      307    10.0  1.458000e+09
# 1          2605    2542      412    10.0  1.485994e+09
# 2          4890     944      301     6.0  1.543363e+09
# 3          2040    5857      228     8.0  1.472083e+09
# 4          5399    5885      139     6.6  1.553904e+09
# ..          ...     ...      ...     ...           ...
# 954        5365    5972      210     9.0  1.552867e+09
# 955       15687    5914      394     8.8  1.679098e+09
# 956        1896    5961      128     6.0  1.468109e+09
# 957        6694    6786       65     6.3  1.578442e+09
# 958        2045     934      549     8.5  1.472256e+09
#
#      X_test_pred_item_pearson  X_test_pred_item_cosine
# 0                    7.682527                 8.338462
# 1                    7.296643                 0.000000
# 2                    7.000000                 7.875000
# 3                    6.312835                 8.014583
# 4                    0.000000                 8.500944
# ..                        ...                      ...
# 954                  8.125247                 7.833333
# 955                  8.799790                 7.531034
# 956                  9.000000                 8.079964
# 957                  0.000000                 7.498271
# 958                  0.000000                 8.133333
#
# [959 rows x 7 columns]

# %%
top_k_df_ItemKNN_pearson = pd.DataFrame(data=df_ItemKNN[['userId',	'movieId', 'X_test_pred_item_pearson']])
top_k_df_ItemKNN_pearson = top_k_df_ItemKNN_pearson[top_k_df_ItemKNN_pearson.X_test_pred_item_pearson > 7.5]
top_k_df_ItemKNN_pearson = top_k_df_ItemKNN_pearson.sort_values(['userId', 'X_test_pred_item_pearson'], ascending=True)
top_k_df_ItemKNN_pearson
# Out:
#      userId  movieId  X_test_pred_item_pearson
# 229     145      381                  9.341011
# 933     415      515                  9.000000
# 83      463      112                  8.000000
# 814     463      420                  8.750000
# 372     463      178                  9.700000
# ..      ...      ...                       ...
# 839   10260      124                 10.000000
# 141   10516      573                  8.348842
# 54    10594      404                  8.500000
# 162   10636       65                  8.092978
# 639   10659      150                  8.253883
#
# [406 rows x 3 columns]

# %%
from recommenders.evaluation.python_evaluation import auc, map_at_k, ndcg_at_k, precision_at_k, recall_at_k
def ranking_metrics(
    data_true,
    data_pred,
    K
):

    eval_map = map_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                    col_rating="rating", col_prediction="X_test_pred_item_pearson",
                    relevancy_method="top_k", k= K)

    eval_ndcg_5 = ndcg_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                      col_rating="rating", col_prediction="X_test_pred_item_pearson",
                      relevancy_method="top_k", k= 5)

    eval_ndcg_10 = ndcg_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                      col_rating="rating", col_prediction="X_test_pred_item_pearson",
                      relevancy_method="top_k", k= K)

    eval_precision_10 = precision_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                               col_rating="rating", col_prediction="X_test_pred_item_pearson",
                               relevancy_method="top_k", k= K)

    eval_precision_5 = precision_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                               col_rating="rating", col_prediction="X_test_pred_item_pearson",
                               relevancy_method="top_k", k= 5)

    eval_recall_10 = recall_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                          col_rating="rating", col_prediction="X_test_pred_item_pearson",
                          relevancy_method="top_k", k= K)

    eval_recall_5 = recall_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                          col_rating="rating", col_prediction="X_test_pred_item_pearson",
                          relevancy_method="top_k", k= 5)

    df_result = pd.DataFrame(
        {
            "MAP": eval_map,
            "nDCG@10": eval_ndcg_10,
            "nDCG@5": eval_ndcg_5,
            "Precision@10": eval_precision_10,
            "Precision@5": eval_precision_5,
            "Recall@10": eval_recall_10,
            "Recall@5": eval_recall_5,
        },
        index=[0]
    )

    return df_result

# %% [markdown]
# ### top_k_df_ItemKNN_pearson

# %%
eval = ranking_metrics(
    data_true=df,
    data_pred=top_k_df_ItemKNN_pearson,
    K=10
)

eval
# Out:
#         MAP   nDCG@10    nDCG@5  Precision@10  Precision@5  Recall@10  \
# 0  0.206581  0.010109  0.013637      0.212195     0.390244   0.185897
#
#    Recall@5
# 0  0.183694

# %%
top_k_df_ItemKNN_cosine = pd.DataFrame(data=df_ItemKNN[['userId',	'movieId', 'X_test_pred_item_cosine']])
top_k_df_ItemKNN_cosine = top_k_df_ItemKNN_cosine[top_k_df_ItemKNN_cosine.X_test_pred_item_cosine > 7.5]
top_k_df_ItemKNN_cosine = top_k_df_ItemKNN_cosine.sort_values(['userId', 'X_test_pred_item_cosine'], ascending=True)
top_k_df_ItemKNN_cosine
# Out:
#      userId  movieId  X_test_pred_item_cosine
# 800     126      220                 8.500000
# 819     145      426                 7.600000
# 933     415      515                 7.666667
# 148     415      206                 8.000000
# 372     463      178                 9.000000
# ..      ...      ...                      ...
# 768   10516      383                 8.360000
# 364   10516      222                 8.397775
# 141   10516      573                 8.700000
# 186   10636      253                 8.316667
# 725   10657      399                 7.957143
#
# [492 rows x 3 columns]

# %%
from recommenders.evaluation.python_evaluation import auc, map_at_k, ndcg_at_k, precision_at_k, recall_at_k
def ranking_metrics(
    data_true,
    data_pred,
    K
):

    eval_map = map_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                    col_rating="rating", col_prediction="X_test_pred_item_cosine",
                    relevancy_method="top_k", k= K)

    eval_ndcg_5 = ndcg_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                      col_rating="rating", col_prediction="X_test_pred_item_cosine",
                      relevancy_method="top_k", k= 5)

    eval_ndcg_10 = ndcg_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                      col_rating="rating", col_prediction="X_test_pred_item_cosine",
                      relevancy_method="top_k", k= K)

    eval_precision_10 = precision_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                               col_rating="rating", col_prediction="X_test_pred_item_cosine",
                               relevancy_method="top_k", k= K)

    eval_precision_5 = precision_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                               col_rating="rating", col_prediction="X_test_pred_item_cosine",
                               relevancy_method="top_k", k= 5)

    eval_recall_10 = recall_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                          col_rating="rating", col_prediction="X_test_pred_item_cosine",
                          relevancy_method="top_k", k= K)

    eval_recall_5 = recall_at_k(data_true, data_pred, col_user="userId", col_item="movieId",
                          col_rating="rating", col_prediction="X_test_pred_item_cosine",
                          relevancy_method="top_k", k= 5)

    df_result = pd.DataFrame(
        {
            "MAP": eval_map,
            "nDCG@10": eval_ndcg_10,
            "nDCG@5": eval_ndcg_5,
            "Precision@10": eval_precision_10,
            "Precision@5": eval_precision_5,
            "Recall@10": eval_recall_10,
            "Recall@5": eval_recall_5,
        },
        index=[0]
    )

    return df_result

# %% [markdown]
# ### top_k_df_ItemKNN_cosine

# %%
eval = ranking_metrics(
    data_true=df,
    data_pred=top_k_df_ItemKNN_cosine,
    K=10
)

eval
# Out:
#         MAP   nDCG@10    nDCG@5  Precision@10  Precision@5  Recall@10  \
# 0  0.222896  0.012024  0.015886      0.215745     0.394043   0.200442
#
#    Recall@5
# 0  0.197538
